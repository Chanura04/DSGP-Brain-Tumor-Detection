# %%
import os


import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
# from unet import build_unet
from tensorflow.keras.metrics import Precision, Recall
 
import random
 

# from metrics import dice_loss, dice_coef
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
# Out:
# C:\Users\chanu\anaconda3\envs\tensorNewGPU\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf
print(tf.test.is_built_with_cuda())
# Out:
# True

# %%
print(tf.sysconfig.get_build_info())
# Out:
# OrderedDict([('cpu_compiler', 'C:/Program Files (x86)/Microsoft Visual Studio/2019/Community/VC/Tools/MSVC/14.29.30133/bin/HostX64/x64/cl.exe'), ('cuda_compute_capabilities', ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']), ('cuda_version', '64_112'), ('cudart_dll_name', 'cudart64_112.dll'), ('cudnn_dll_name', 'cudnn64_8.dll'), ('cudnn_version', '64_8'), ('is_cuda_build', True), ('is_rocm_build', False), ('is_tensorrt_build', False), ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll'), ('nvcuda_dll_name', 'nvcuda.dll')])

# %%
import tensorflow as tf

print("GPU in use:", tf.test.gpu_device_name())
# Out:
# GPU in use: /device:GPU:0

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    details = tf.config.experimental.get_device_details(gpus[0])
    print(details)
# Out:
# {'device_name': 'NVIDIA GeForce RTX 4050 Laptop GPU', 'compute_capability': (8, 9)}

# %%
gpus=tf.config.list_physical_devices('GPU')
if gpus:
    print('GPU available')
else:
    print('GPU not available')
tf.config.list_physical_devices('GPU')
# Out:
# GPU available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf

# List logical devices (after setting visible devices)
logical_gpus = tf.config.list_logical_devices('GPU')
print("Logical GPUs:", logical_gpus)
# Out:
# Logical GPUs: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
tf.debugging.set_log_device_placement(False)

# %%
H = 256
W = 256

# %%
# Set a global seed
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
from tensorflow.keras import backend as K

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

# def dice_loss(y_true, y_pred):
#     return 1.0 - dice_coef(y_true, y_pred)
def dice_loss(y_true, y_pred):
    smooth = 1.0
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

# %%
# def conv_block(inputs, num_filters):
#     x = Conv2D(num_filters, 3, padding="same")(inputs)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)

#     x = Conv2D(num_filters, 3, padding="same")(x)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)

#     return x


from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def conv_block(x, num_filters, dropout_rate=0.0, reg=1e-4):
    x = Conv2D(
        num_filters,
        3,
        padding="same",
        kernel_initializer="he_normal",
        kernel_regularizer=l2(reg)
    )(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    x = Conv2D(
        num_filters,
        3,
        padding="same",
        kernel_initializer="he_normal",
        kernel_regularizer=l2(reg)
    )(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    return x


def encoder_block(inputs, num_filters, dropout_rate):
    x = conv_block(inputs, num_filters, dropout_rate)
    p = MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(inputs, skip_features, num_filters, dropout_rate):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters, dropout_rate)
    return x

    
# def decoder_block(inputs, skip_features, num_filters):
#     x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(inputs)
#     x = Concatenate()([x, skip_features])
#     x = conv_block(x, num_filters)
#     return x

# def build_unet(input_shape):
#     inputs = Input(input_shape)

#     s1, p1 = encoder_block(inputs, 64)
#     s2, p2 = encoder_block(p1, 128)
#     s3, p3 = encoder_block(p2, 256)
#     s4, p4 = encoder_block(p3, 512)

#     # print(s1.shape, s2.shape, s3.shape, s4.shape)
#     # print(p1.shape, p2.shape, p3.shape, p4.shape)

#     b1 = conv_block(p4, 1024)

#     d1 = decoder_block(b1, s4, 512)
#     d2 = decoder_block(d1, s3, 256)
#     d3 = decoder_block(d2, s2, 128)
#     d4 = decoder_block(d3, s1, 64)

#     outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

#     model = Model(inputs, outputs, name="UNET")
#     return model
def build_unet(input_shape):
    inputs = Input(input_shape)

    # Encoder (low dropout)
    s1, p1 = encoder_block(inputs, 32, 0.1)
    s2, p2 = encoder_block(p1, 64, 0.3)
    s3, p3 = encoder_block(p2, 128, 0.4)

    # Bottleneck (highest dropout)
    b1 = conv_block(p3, 256, dropout_rate=0.5)

    # Decoder (moderate dropout)
    d1 = decoder_block(b1, s3, 128, 0.4)
    d2 = decoder_block(d1, s2, 64, 0.3)
    d3 = decoder_block(d2, s1, 32, 0.1)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d3)

    model = Model(inputs, outputs, name="UNET_Optimized")
    return model


if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_unet(input_shape)
    model.summary()
# Out:
# Model: "UNET_Optimized"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  leaky_re_lu (LeakyReLU)        (None, 256, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 32  0           ['leaky_re_lu[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['dropout[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 256, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['leaky_re_lu_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 128, 128, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 64  0           ['leaky_re_lu_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['dropout_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 128, 128, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 128)  0           ['leaky_re_lu_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['dropout_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['leaky_re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 256)  0           ['batch_normalization_6[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 256)  0           ['leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['dropout_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 32, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 128)  131200     ['leaky_re_lu_7[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  295040      ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_8[0][0]']
#
#  dropout_4 (Dropout)            (None, 64, 64, 128)  0           ['leaky_re_lu_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 128)  147584      ['dropout_4[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 64  32832      ['leaky_re_lu_9[0][0]']
#  spose)                         )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_1[0][0]',
#                                 8)                                'leaky_re_lu_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 128, 128, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 128, 128, 64  0           ['leaky_re_lu_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_5[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 128, 128, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 32  8224       ['leaky_re_lu_11[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'leaky_re_lu_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 256, 256, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 256, 256, 32  0           ['leaky_re_lu_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_6[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 256, 256, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 1)  33          ['leaky_re_lu_13[0][0]']
#
# ==================================================================================================
# Total params: 1,931,233
# Trainable params: 1,928,417
# Non-trainable params: 2,816
# __________________________________________________________________________________________________

# %%
# def read_mask(path):
#     x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
#     if x is None:
#         raise ValueError(f"Mask not found or unreadable: {path}")
#     x = cv2.resize(x, (W, H))
#     return x
# print(read_mask("C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\masks"))

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# def load_dataset(path, split=0.2):
#     images = sorted(glob(os.path.join(path, "images", "*.png")))
#     masks = sorted(glob(os.path.join(path, "masks", "*.png")))

#     split_size = int(len(images) * split)

#     train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
#     train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

#     train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
#     train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

#     return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)
def load_dataset(path, split=0.2, max_samples=None):
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks  = sorted(glob(os.path.join(path, "masks", "*.png")))

    assert len(images) == len(masks), "Images and masks count mismatch"

    # 🔹 Limit dataset size
    if max_samples is not None:
        images = images[:max_samples]
        masks  = masks[:max_samples]

    # 🔹 Train / temp split
    train_x, temp_x, train_y, temp_y = train_test_split(
        images, masks,
        test_size=2 * split,
        random_state=42,
        shuffle=True
    )

    # 🔹 Validation / Test split
    valid_x, test_x, valid_y, test_y = train_test_split(
        temp_x, temp_y,
        test_size=0.5,
        random_state=42
    )

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))   ## (h, w)
    x = x / 255.0               ## (h, w)
    x = x.astype(np.float32)    ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 12
    lr = 1e-4
    num_epochs = 100
    model_path = os.path.join("C:\\Projects Datasets\\model_details\\unet_4", "model_2.h5")
    csv_path = os.path.join("C:\\Projects Datasets\\model_details\\unet_4", "log.csv")

    """ Dataset """
    # dataset_path = "C:\\Projects Datasets\\Segmentation_1\\Segmentation_filtered"
    dataset_path="C:\Projects Datasets\Segmentation_1\Segmentation"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path,0.2,1200)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test : {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    test_dataset  = tf_dataset(test_x, test_y, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    # model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=["accuracy", dice_coef])
    model.compile( loss=dice_loss, optimizer=Adam(lr), metrics=["accuracy", dice_coef, Precision(name="precision"), Recall(name="recall")] )

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=False),
    ]

    history = model.fit(
        train_dataset,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 720 - 720
# Valid: 240 - 240
# Test : 240 - 240
# Epoch 1/100
# 60/60 [==============================] - ETA: 0s - loss: 1.2208 - accuracy: 0.8427 - dice_coef: 0.0373 - precision: 0.0315 - recall: 0.3802
# Epoch 1: val_loss improved from inf to 1.20524, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 34s 367ms/step - loss: 1.2208 - accuracy: 0.8427 - dice_coef: 0.0373 - precision: 0.0315 - recall: 0.3802 - val_loss: 1.2052 - val_accuracy: 0.6298 - val_dice_coef: 0.0299 - val_precision: 0.0223 - val_recall: 0.6960 - lr: 1.0000e-04
# Epoch 2/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1484 - accuracy: 0.8258 - dice_coef: 0.0701 - precision: 0.0555 - recall: 0.7882
# Epoch 2: val_loss improved from 1.20524 to 1.17840, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 22s 358ms/step - loss: 1.1484 - accuracy: 0.8258 - dice_coef: 0.0701 - precision: 0.0555 - recall: 0.7882 - val_loss: 1.1784 - val_accuracy: 0.8831 - val_dice_coef: 0.0277 - val_precision: 0.0201 - val_recall: 0.1829 - lr: 1.0000e-04
# Epoch 3/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0963 - accuracy: 0.9100 - dice_coef: 0.1037 - precision: 0.1053 - recall: 0.8018
# Epoch 3: val_loss improved from 1.17840 to 1.16625, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 356ms/step - loss: 1.0963 - accuracy: 0.9100 - dice_coef: 0.1037 - precision: 0.1053 - recall: 0.8018 - val_loss: 1.1662 - val_accuracy: 0.9694 - val_dice_coef: 0.0286 - val_precision: 0.0353 - val_recall: 0.0588 - lr: 1.0000e-04
# Epoch 4/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0551 - accuracy: 0.9456 - dice_coef: 0.1362 - precision: 0.1615 - recall: 0.7685
# Epoch 4: val_loss improved from 1.16625 to 1.16060, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 355ms/step - loss: 1.0551 - accuracy: 0.9456 - dice_coef: 0.1362 - precision: 0.1615 - recall: 0.7685 - val_loss: 1.1606 - val_accuracy: 0.9784 - val_dice_coef: 0.0274 - val_precision: 0.0294 - val_recall: 0.0248 - lr: 1.0000e-04
# Epoch 5/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0186 - accuracy: 0.9630 - dice_coef: 0.1670 - precision: 0.2213 - recall: 0.7371
# Epoch 5: val_loss did not improve from 1.16060
# 60/60 [==============================] - 21s 353ms/step - loss: 1.0186 - accuracy: 0.9630 - dice_coef: 0.1670 - precision: 0.2213 - recall: 0.7371 - val_loss: 1.1627 - val_accuracy: 0.9795 - val_dice_coef: 0.0206 - val_precision: 0.0028 - val_recall: 0.0020 - lr: 1.0000e-04
# Epoch 6/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9823 - accuracy: 0.9729 - dice_coef: 0.1993 - precision: 0.2856 - recall: 0.7219
# Epoch 6: val_loss improved from 1.16060 to 1.16019, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 22s 359ms/step - loss: 0.9823 - accuracy: 0.9729 - dice_coef: 0.1993 - precision: 0.2856 - recall: 0.7219 - val_loss: 1.1602 - val_accuracy: 0.9818 - val_dice_coef: 0.0196 - val_precision: 0.0131 - val_recall: 0.0069 - lr: 1.0000e-04
# Epoch 7/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9472 - accuracy: 0.9784 - dice_coef: 0.2312 - precision: 0.3425 - recall: 0.7097
# Epoch 7: val_loss improved from 1.16019 to 1.14859, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.9472 - accuracy: 0.9784 - dice_coef: 0.2312 - precision: 0.3425 - recall: 0.7097 - val_loss: 1.1486 - val_accuracy: 0.9856 - val_dice_coef: 0.0284 - val_precision: 0.1007 - val_recall: 0.0254 - lr: 1.0000e-04
# Epoch 8/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9095 - accuracy: 0.9826 - dice_coef: 0.2663 - precision: 0.4068 - recall: 0.7033
# Epoch 8: val_loss improved from 1.14859 to 1.13629, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.9095 - accuracy: 0.9826 - dice_coef: 0.2663 - precision: 0.4068 - recall: 0.7033 - val_loss: 1.1363 - val_accuracy: 0.9880 - val_dice_coef: 0.0384 - val_precision: 0.5118 - val_recall: 0.0388 - lr: 1.0000e-04
# Epoch 9/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8785 - accuracy: 0.9848 - dice_coef: 0.2952 - precision: 0.4509 - recall: 0.6869
# Epoch 9: val_loss improved from 1.13629 to 1.10876, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.8785 - accuracy: 0.9848 - dice_coef: 0.2952 - precision: 0.4509 - recall: 0.6869 - val_loss: 1.1088 - val_accuracy: 0.9885 - val_dice_coef: 0.0640 - val_precision: 0.7167 - val_recall: 0.0791 - lr: 1.0000e-04
# Epoch 10/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8384 - accuracy: 0.9867 - dice_coef: 0.3335 - precision: 0.4996 - recall: 0.6964
# Epoch 10: val_loss improved from 1.10876 to 1.07057, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 356ms/step - loss: 0.8384 - accuracy: 0.9867 - dice_coef: 0.3335 - precision: 0.4996 - recall: 0.6964 - val_loss: 1.0706 - val_accuracy: 0.9889 - val_dice_coef: 0.1004 - val_precision: 0.7514 - val_recall: 0.1299 - lr: 1.0000e-04
# Epoch 11/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8048 - accuracy: 0.9878 - dice_coef: 0.3655 - precision: 0.5320 - recall: 0.6935
# Epoch 11: val_loss improved from 1.07057 to 1.04609, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 356ms/step - loss: 0.8048 - accuracy: 0.9878 - dice_coef: 0.3655 - precision: 0.5320 - recall: 0.6935 - val_loss: 1.0461 - val_accuracy: 0.9891 - val_dice_coef: 0.1235 - val_precision: 0.7603 - val_recall: 0.1501 - lr: 1.0000e-04
# Epoch 12/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7759 - accuracy: 0.9886 - dice_coef: 0.3931 - precision: 0.5594 - recall: 0.6822
# Epoch 12: val_loss improved from 1.04609 to 1.03552, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.7759 - accuracy: 0.9886 - dice_coef: 0.3931 - precision: 0.5594 - recall: 0.6822 - val_loss: 1.0355 - val_accuracy: 0.9893 - val_dice_coef: 0.1328 - val_precision: 0.8289 - val_recall: 0.1471 - lr: 1.0000e-04
# Epoch 13/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7426 - accuracy: 0.9894 - dice_coef: 0.4252 - precision: 0.5898 - recall: 0.6860
# Epoch 13: val_loss improved from 1.03552 to 0.97229, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.7426 - accuracy: 0.9894 - dice_coef: 0.4252 - precision: 0.5898 - recall: 0.6860 - val_loss: 0.9723 - val_accuracy: 0.9896 - val_dice_coef: 0.1949 - val_precision: 0.7373 - val_recall: 0.2208 - lr: 1.0000e-04
# Epoch 14/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7032 - accuracy: 0.9904 - dice_coef: 0.4635 - precision: 0.6273 - recall: 0.6942
# Epoch 14: val_loss improved from 0.97229 to 0.89326, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.7032 - accuracy: 0.9904 - dice_coef: 0.4635 - precision: 0.6273 - recall: 0.6942 - val_loss: 0.8933 - val_accuracy: 0.9899 - val_dice_coef: 0.2729 - val_precision: 0.7006 - val_recall: 0.3096 - lr: 1.0000e-04
# Epoch 15/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.9903 - dice_coef: 0.4811 - precision: 0.6258 - recall: 0.6806
# Epoch 15: val_loss improved from 0.89326 to 0.85321, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 356ms/step - loss: 0.6846 - accuracy: 0.9903 - dice_coef: 0.4811 - precision: 0.6258 - recall: 0.6806 - val_loss: 0.8532 - val_accuracy: 0.9906 - val_dice_coef: 0.3121 - val_precision: 0.7674 - val_recall: 0.3347 - lr: 1.0000e-04
# Epoch 16/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.9912 - dice_coef: 0.5188 - precision: 0.6623 - recall: 0.6996
# Epoch 16: val_loss improved from 0.85321 to 0.83661, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.6461 - accuracy: 0.9912 - dice_coef: 0.5188 - precision: 0.6623 - recall: 0.6996 - val_loss: 0.8366 - val_accuracy: 0.9905 - val_dice_coef: 0.3278 - val_precision: 0.7543 - val_recall: 0.3350 - lr: 1.0000e-04
# Epoch 17/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6179 - accuracy: 0.9917 - dice_coef: 0.5461 - precision: 0.6887 - recall: 0.7035
# Epoch 17: val_loss improved from 0.83661 to 0.83155, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.6179 - accuracy: 0.9917 - dice_coef: 0.5461 - precision: 0.6887 - recall: 0.7035 - val_loss: 0.8316 - val_accuracy: 0.9905 - val_dice_coef: 0.3321 - val_precision: 0.7706 - val_recall: 0.3233 - lr: 1.0000e-04
# Epoch 18/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5976 - accuracy: 0.9918 - dice_coef: 0.5657 - precision: 0.6946 - recall: 0.7049
# Epoch 18: val_loss improved from 0.83155 to 0.77502, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.5976 - accuracy: 0.9918 - dice_coef: 0.5657 - precision: 0.6946 - recall: 0.7049 - val_loss: 0.7750 - val_accuracy: 0.9906 - val_dice_coef: 0.3879 - val_precision: 0.7245 - val_recall: 0.3876 - lr: 1.0000e-04
# Epoch 19/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5724 - accuracy: 0.9924 - dice_coef: 0.5901 - precision: 0.7235 - recall: 0.7060
# Epoch 19: val_loss did not improve from 0.77502
# 60/60 [==============================] - 21s 355ms/step - loss: 0.5724 - accuracy: 0.9924 - dice_coef: 0.5901 - precision: 0.7235 - recall: 0.7060 - val_loss: 0.7850 - val_accuracy: 0.9909 - val_dice_coef: 0.3772 - val_precision: 0.7965 - val_recall: 0.3449 - lr: 1.0000e-04
# Epoch 20/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5511 - accuracy: 0.9927 - dice_coef: 0.6107 - precision: 0.7444 - recall: 0.7035
# Epoch 20: val_loss improved from 0.77502 to 0.75198, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.5511 - accuracy: 0.9927 - dice_coef: 0.6107 - precision: 0.7444 - recall: 0.7035 - val_loss: 0.7520 - val_accuracy: 0.9910 - val_dice_coef: 0.4095 - val_precision: 0.7774 - val_recall: 0.3717 - lr: 1.0000e-04
# Epoch 21/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5375 - accuracy: 0.9928 - dice_coef: 0.6237 - precision: 0.7453 - recall: 0.7089
# Epoch 21: val_loss improved from 0.75198 to 0.68130, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.5375 - accuracy: 0.9928 - dice_coef: 0.6237 - precision: 0.7453 - recall: 0.7089 - val_loss: 0.6813 - val_accuracy: 0.9913 - val_dice_coef: 0.4796 - val_precision: 0.7444 - val_recall: 0.4661 - lr: 1.0000e-04
# Epoch 22/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5180 - accuracy: 0.9930 - dice_coef: 0.6426 - precision: 0.7539 - recall: 0.7172
# Epoch 22: val_loss did not improve from 0.68130
# 60/60 [==============================] - 21s 354ms/step - loss: 0.5180 - accuracy: 0.9930 - dice_coef: 0.6426 - precision: 0.7539 - recall: 0.7172 - val_loss: 0.7014 - val_accuracy: 0.9909 - val_dice_coef: 0.4588 - val_precision: 0.7192 - val_recall: 0.4338 - lr: 1.0000e-04
# Epoch 23/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.9932 - dice_coef: 0.6536 - precision: 0.7708 - recall: 0.7103
# Epoch 23: val_loss improved from 0.68130 to 0.67270, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.5063 - accuracy: 0.9932 - dice_coef: 0.6536 - precision: 0.7708 - recall: 0.7103 - val_loss: 0.6727 - val_accuracy: 0.9917 - val_dice_coef: 0.4869 - val_precision: 0.8103 - val_recall: 0.4302 - lr: 1.0000e-04
# Epoch 24/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5027 - accuracy: 0.9930 - dice_coef: 0.6566 - precision: 0.7611 - recall: 0.7069
# Epoch 24: val_loss did not improve from 0.67270
# 60/60 [==============================] - 21s 355ms/step - loss: 0.5027 - accuracy: 0.9930 - dice_coef: 0.6566 - precision: 0.7611 - recall: 0.7069 - val_loss: 0.6971 - val_accuracy: 0.9913 - val_dice_coef: 0.4620 - val_precision: 0.7983 - val_recall: 0.3938 - lr: 1.0000e-04
# Epoch 25/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.9936 - dice_coef: 0.6813 - precision: 0.7923 - recall: 0.7193
# Epoch 25: val_loss did not improve from 0.67270
# 60/60 [==============================] - 21s 355ms/step - loss: 0.4775 - accuracy: 0.9936 - dice_coef: 0.6813 - precision: 0.7923 - recall: 0.7193 - val_loss: 0.6766 - val_accuracy: 0.9916 - val_dice_coef: 0.4819 - val_precision: 0.8338 - val_recall: 0.4016 - lr: 1.0000e-04
# Epoch 26/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.9936 - dice_coef: 0.6883 - precision: 0.7951 - recall: 0.7194
# Epoch 26: val_loss improved from 0.67270 to 0.60000, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.4700 - accuracy: 0.9936 - dice_coef: 0.6883 - precision: 0.7951 - recall: 0.7194 - val_loss: 0.6000 - val_accuracy: 0.9919 - val_dice_coef: 0.5580 - val_precision: 0.7611 - val_recall: 0.5201 - lr: 1.0000e-04
# Epoch 27/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4596 - accuracy: 0.9938 - dice_coef: 0.6982 - precision: 0.8048 - recall: 0.7174
# Epoch 27: val_loss improved from 0.60000 to 0.59673, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 356ms/step - loss: 0.4596 - accuracy: 0.9938 - dice_coef: 0.6982 - precision: 0.8048 - recall: 0.7174 - val_loss: 0.5967 - val_accuracy: 0.9919 - val_dice_coef: 0.5607 - val_precision: 0.7621 - val_recall: 0.5139 - lr: 1.0000e-04
# Epoch 28/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4478 - accuracy: 0.9939 - dice_coef: 0.7094 - precision: 0.8071 - recall: 0.7286
# Epoch 28: val_loss improved from 0.59673 to 0.56588, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.4478 - accuracy: 0.9939 - dice_coef: 0.7094 - precision: 0.8071 - recall: 0.7286 - val_loss: 0.5659 - val_accuracy: 0.9923 - val_dice_coef: 0.5911 - val_precision: 0.7724 - val_recall: 0.5507 - lr: 1.0000e-04
# Epoch 29/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4314 - accuracy: 0.9942 - dice_coef: 0.7253 - precision: 0.8250 - recall: 0.7365
# Epoch 29: val_loss did not improve from 0.56588
# 60/60 [==============================] - 21s 354ms/step - loss: 0.4314 - accuracy: 0.9942 - dice_coef: 0.7253 - precision: 0.8250 - recall: 0.7365 - val_loss: 0.5850 - val_accuracy: 0.9919 - val_dice_coef: 0.5714 - val_precision: 0.7505 - val_recall: 0.5304 - lr: 1.0000e-04
# Epoch 30/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4250 - accuracy: 0.9943 - dice_coef: 0.7312 - precision: 0.8263 - recall: 0.7379
# Epoch 30: val_loss did not improve from 0.56588
# 60/60 [==============================] - 21s 354ms/step - loss: 0.4250 - accuracy: 0.9943 - dice_coef: 0.7312 - precision: 0.8263 - recall: 0.7379 - val_loss: 0.5932 - val_accuracy: 0.9922 - val_dice_coef: 0.5627 - val_precision: 0.8132 - val_recall: 0.4820 - lr: 1.0000e-04
# Epoch 31/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4213 - accuracy: 0.9943 - dice_coef: 0.7344 - precision: 0.8249 - recall: 0.7405
# Epoch 31: val_loss did not improve from 0.56588
# 60/60 [==============================] - 21s 354ms/step - loss: 0.4213 - accuracy: 0.9943 - dice_coef: 0.7344 - precision: 0.8249 - recall: 0.7405 - val_loss: 0.5880 - val_accuracy: 0.9921 - val_dice_coef: 0.5674 - val_precision: 0.7933 - val_recall: 0.4888 - lr: 1.0000e-04
# Epoch 32/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4081 - accuracy: 0.9945 - dice_coef: 0.7471 - precision: 0.8387 - recall: 0.7459
# Epoch 32: val_loss did not improve from 0.56588
# 60/60 [==============================] - 21s 354ms/step - loss: 0.4081 - accuracy: 0.9945 - dice_coef: 0.7471 - precision: 0.8387 - recall: 0.7459 - val_loss: 0.5920 - val_accuracy: 0.9918 - val_dice_coef: 0.5629 - val_precision: 0.7756 - val_recall: 0.4897 - lr: 1.0000e-04
# Epoch 33/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4085 - accuracy: 0.9944 - dice_coef: 0.7462 - precision: 0.8336 - recall: 0.7402
# Epoch 33: val_loss improved from 0.56588 to 0.55753, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.4085 - accuracy: 0.9944 - dice_coef: 0.7462 - precision: 0.8336 - recall: 0.7402 - val_loss: 0.5575 - val_accuracy: 0.9921 - val_dice_coef: 0.5969 - val_precision: 0.7491 - val_recall: 0.5538 - lr: 1.0000e-04
# Epoch 34/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.9946 - dice_coef: 0.7556 - precision: 0.8433 - recall: 0.7466
# Epoch 34: val_loss improved from 0.55753 to 0.54263, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.3987 - accuracy: 0.9946 - dice_coef: 0.7556 - precision: 0.8433 - recall: 0.7466 - val_loss: 0.5426 - val_accuracy: 0.9925 - val_dice_coef: 0.6114 - val_precision: 0.7866 - val_recall: 0.5502 - lr: 1.0000e-04
# Epoch 35/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.9947 - dice_coef: 0.7624 - precision: 0.8466 - recall: 0.7534
# Epoch 35: val_loss did not improve from 0.54263
# 60/60 [==============================] - 21s 355ms/step - loss: 0.3914 - accuracy: 0.9947 - dice_coef: 0.7624 - precision: 0.8466 - recall: 0.7534 - val_loss: 0.5485 - val_accuracy: 0.9922 - val_dice_coef: 0.6050 - val_precision: 0.7685 - val_recall: 0.5470 - lr: 1.0000e-04
# Epoch 36/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3899 - accuracy: 0.9946 - dice_coef: 0.7634 - precision: 0.8386 - recall: 0.7531
# Epoch 36: val_loss improved from 0.54263 to 0.52948, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.3899 - accuracy: 0.9946 - dice_coef: 0.7634 - precision: 0.8386 - recall: 0.7531 - val_loss: 0.5295 - val_accuracy: 0.9923 - val_dice_coef: 0.6236 - val_precision: 0.7529 - val_recall: 0.5811 - lr: 1.0000e-04
# Epoch 37/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.9949 - dice_coef: 0.7762 - precision: 0.8585 - recall: 0.7600
# Epoch 37: val_loss improved from 0.52948 to 0.51327, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 22s 358ms/step - loss: 0.3767 - accuracy: 0.9949 - dice_coef: 0.7762 - precision: 0.8585 - recall: 0.7600 - val_loss: 0.5133 - val_accuracy: 0.9927 - val_dice_coef: 0.6394 - val_precision: 0.7787 - val_recall: 0.5907 - lr: 1.0000e-04
# Epoch 38/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.9948 - dice_coef: 0.7753 - precision: 0.8542 - recall: 0.7578
# Epoch 38: val_loss did not improve from 0.51327
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3772 - accuracy: 0.9948 - dice_coef: 0.7753 - precision: 0.8542 - recall: 0.7578 - val_loss: 0.5313 - val_accuracy: 0.9927 - val_dice_coef: 0.6209 - val_precision: 0.8222 - val_recall: 0.5368 - lr: 1.0000e-04
# Epoch 39/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3762 - accuracy: 0.9948 - dice_coef: 0.7758 - precision: 0.8517 - recall: 0.7578
# Epoch 39: val_loss improved from 0.51327 to 0.50771, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.3762 - accuracy: 0.9948 - dice_coef: 0.7758 - precision: 0.8517 - recall: 0.7578 - val_loss: 0.5077 - val_accuracy: 0.9930 - val_dice_coef: 0.6441 - val_precision: 0.8343 - val_recall: 0.5594 - lr: 1.0000e-04
# Epoch 40/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.9951 - dice_coef: 0.7889 - precision: 0.8680 - recall: 0.7665
# Epoch 40: val_loss did not improve from 0.50771
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3627 - accuracy: 0.9951 - dice_coef: 0.7889 - precision: 0.8680 - recall: 0.7665 - val_loss: 0.5367 - val_accuracy: 0.9924 - val_dice_coef: 0.6147 - val_precision: 0.7769 - val_recall: 0.5471 - lr: 1.0000e-04
# Epoch 41/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3596 - accuracy: 0.9951 - dice_coef: 0.7915 - precision: 0.8667 - recall: 0.7703
# Epoch 41: val_loss did not improve from 0.50771
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3596 - accuracy: 0.9951 - dice_coef: 0.7915 - precision: 0.8667 - recall: 0.7703 - val_loss: 0.5141 - val_accuracy: 0.9926 - val_dice_coef: 0.6368 - val_precision: 0.7837 - val_recall: 0.5729 - lr: 1.0000e-04
# Epoch 42/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3546 - accuracy: 0.9952 - dice_coef: 0.7962 - precision: 0.8715 - recall: 0.7710
# Epoch 42: val_loss did not improve from 0.50771
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3546 - accuracy: 0.9952 - dice_coef: 0.7962 - precision: 0.8715 - recall: 0.7710 - val_loss: 0.5182 - val_accuracy: 0.9928 - val_dice_coef: 0.6323 - val_precision: 0.8261 - val_recall: 0.5384 - lr: 1.0000e-04
# Epoch 43/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3555 - accuracy: 0.9952 - dice_coef: 0.7948 - precision: 0.8686 - recall: 0.7702
# Epoch 43: val_loss improved from 0.50771 to 0.48553, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.3555 - accuracy: 0.9952 - dice_coef: 0.7948 - precision: 0.8686 - recall: 0.7702 - val_loss: 0.4855 - val_accuracy: 0.9928 - val_dice_coef: 0.6646 - val_precision: 0.7618 - val_recall: 0.6305 - lr: 1.0000e-04
# Epoch 44/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3483 - accuracy: 0.9953 - dice_coef: 0.8016 - precision: 0.8717 - recall: 0.7748
# Epoch 44: val_loss did not improve from 0.48553
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3483 - accuracy: 0.9953 - dice_coef: 0.8016 - precision: 0.8717 - recall: 0.7748 - val_loss: 0.4983 - val_accuracy: 0.9930 - val_dice_coef: 0.6513 - val_precision: 0.8258 - val_recall: 0.5641 - lr: 1.0000e-04
# Epoch 45/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.9953 - dice_coef: 0.8043 - precision: 0.8723 - recall: 0.7781
# Epoch 45: val_loss did not improve from 0.48553
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3451 - accuracy: 0.9953 - dice_coef: 0.8043 - precision: 0.8723 - recall: 0.7781 - val_loss: 0.4857 - val_accuracy: 0.9930 - val_dice_coef: 0.6635 - val_precision: 0.8132 - val_recall: 0.5842 - lr: 1.0000e-04
# Epoch 46/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3371 - accuracy: 0.9955 - dice_coef: 0.8120 - precision: 0.8867 - recall: 0.7798
# Epoch 46: val_loss improved from 0.48553 to 0.47816, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.3371 - accuracy: 0.9955 - dice_coef: 0.8120 - precision: 0.8867 - recall: 0.7798 - val_loss: 0.4782 - val_accuracy: 0.9926 - val_dice_coef: 0.6707 - val_precision: 0.7328 - val_recall: 0.6594 - lr: 1.0000e-04
# Epoch 47/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.9954 - dice_coef: 0.8088 - precision: 0.8774 - recall: 0.7797
# Epoch 47: val_loss improved from 0.47816 to 0.47337, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 357ms/step - loss: 0.3399 - accuracy: 0.9954 - dice_coef: 0.8088 - precision: 0.8774 - recall: 0.7797 - val_loss: 0.4734 - val_accuracy: 0.9932 - val_dice_coef: 0.6751 - val_precision: 0.8117 - val_recall: 0.6077 - lr: 1.0000e-04
# Epoch 48/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3361 - accuracy: 0.9955 - dice_coef: 0.8122 - precision: 0.8866 - recall: 0.7753
# Epoch 48: val_loss did not improve from 0.47337
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3361 - accuracy: 0.9955 - dice_coef: 0.8122 - precision: 0.8866 - recall: 0.7753 - val_loss: 0.4764 - val_accuracy: 0.9929 - val_dice_coef: 0.6716 - val_precision: 0.7754 - val_recall: 0.6208 - lr: 1.0000e-04
# Epoch 49/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.9955 - dice_coef: 0.8123 - precision: 0.8832 - recall: 0.7787
# Epoch 49: val_loss improved from 0.47337 to 0.44481, saving model to C:\Projects Datasets\model_details\unet_4\model_2.h5
# 60/60 [==============================] - 21s 358ms/step - loss: 0.3355 - accuracy: 0.9955 - dice_coef: 0.8123 - precision: 0.8832 - recall: 0.7787 - val_loss: 0.4448 - val_accuracy: 0.9935 - val_dice_coef: 0.7029 - val_precision: 0.8090 - val_recall: 0.6483 - lr: 1.0000e-04
# Epoch 50/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.9956 - dice_coef: 0.8206 - precision: 0.8926 - recall: 0.7834
# Epoch 50: val_loss did not improve from 0.44481
# 60/60 [==============================] - 21s 355ms/step - loss: 0.3269 - accuracy: 0.9956 - dice_coef: 0.8206 - precision: 0.8926 - recall: 0.7834 - val_loss: 0.4507 - val_accuracy: 0.9934 - val_dice_coef: 0.6966 - val_precision: 0.7957 - val_recall: 0.6521 - lr: 1.0000e-04
# Epoch 51/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3272 - accuracy: 0.9956 - dice_coef: 0.8199 - precision: 0.8870 - recall: 0.7890
# Epoch 51: val_loss did not improve from 0.44481
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3272 - accuracy: 0.9956 - dice_coef: 0.8199 - precision: 0.8870 - recall: 0.7890 - val_loss: 0.4742 - val_accuracy: 0.9930 - val_dice_coef: 0.6727 - val_precision: 0.7849 - val_recall: 0.6178 - lr: 1.0000e-04
# Epoch 52/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.9958 - dice_coef: 0.8310 - precision: 0.8955 - recall: 0.7988
# Epoch 52: val_loss did not improve from 0.44481
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3157 - accuracy: 0.9958 - dice_coef: 0.8310 - precision: 0.8955 - recall: 0.7988 - val_loss: 0.4510 - val_accuracy: 0.9935 - val_dice_coef: 0.6955 - val_precision: 0.8227 - val_recall: 0.6238 - lr: 1.0000e-04
# Epoch 53/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.9958 - dice_coef: 0.8289 - precision: 0.8938 - recall: 0.7952
# Epoch 53: val_loss did not improve from 0.44481
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3174 - accuracy: 0.9958 - dice_coef: 0.8289 - precision: 0.8938 - recall: 0.7952 - val_loss: 0.4633 - val_accuracy: 0.9933 - val_dice_coef: 0.6828 - val_precision: 0.8140 - val_recall: 0.6098 - lr: 1.0000e-04
# Epoch 54/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.9958 - dice_coef: 0.8336 - precision: 0.8975 - recall: 0.7983
# Epoch 54: val_loss did not improve from 0.44481
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 60/60 [==============================] - 21s 354ms/step - loss: 0.3122 - accuracy: 0.9958 - dice_coef: 0.8336 - precision: 0.8975 - recall: 0.7983 - val_loss: 0.4525 - val_accuracy: 0.9935 - val_dice_coef: 0.6931 - val_precision: 0.8155 - val_recall: 0.6279 - lr: 1.0000e-04

# %%
""" Evaluate on test set """
results = model.evaluate(test_dataset)
print("\nEvaluation Metrics:")
for metric_name, metric_value in zip(model.metrics_names, results):
    print(f"{metric_name}: {metric_value:.4f}")
# Out:
# 20/20 [==============================] - 2s 110ms/step - loss: 0.4441 - accuracy: 0.9933 - dice_coef: 0.7016 - precision: 0.8447 - recall: 0.6233
#
# Evaluation Metrics:
# loss: 0.4441
# accuracy: 0.9933
# dice_coef: 0.7016
# precision: 0.8447
# recall: 0.6233

# %%
import pickle
with open("C:\\Projects Datasets\\model_details\\unet_4\\history2.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %%
import pickle
import matplotlib.pyplot as plt

with open("C:\\Projects Datasets\\model_details\\unet_4\\history2.pkl", "rb") as f:
    history_dict = pickle.load(f)

plt.plot(history_dict['loss'], label='Training Loss')
plt.plot(history_dict['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history_dict['dice_coef'], label='Training Dice Coefficient')
plt.plot(history_dict['val_dice_coef'], label='Validation Dice Coefficient')
plt.xlabel('Epochs')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
print("Final Training Dice:", history_dict['dice_coef'][-1])
print("Final Validation Dice:", history_dict['val_dice_coef'][-1])
# print(history_dict['accuracy'][-1]
# Out:
# Final Training Dice: 0.8336493372917175
# Final Validation Dice: 0.6931350827217102

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

model = load_model(
    "C:\\Projects Datasets\\model_details\\unet_4\\model_2.h5",
    custom_objects={"dice_coef": dice_coef},
    compile=False
)

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="binary_crossentropy",  # or dice_loss
    metrics=["accuracy", dice_coef]
)

loss, accuracy, dice = model.evaluate(test_dataset)

print(f"Loss is {loss}")
print(f"Accuracy is {accuracy}")
print(f"Dice_Coef is {dice}")
# Out:
# 20/20 [==============================] - 3s 107ms/step - loss: 0.1928 - accuracy: 0.9932 - dice_coef: 0.7019
# Loss is 0.19284628331661224
# Accuracy is 0.9932205080986023
# Dice_Coef is 0.7019380927085876

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV log
csv_path = "C:\\Projects Datasets\\model_details\\unet_4\\log.csv"
log_data = pd.read_csv(csv_path)

# Inspect available columns
print(log_data.columns)
# Out:
# Index(['epoch', 'accuracy', 'dice_coef', 'loss', 'lr', 'precision', 'recall',
#        'val_accuracy', 'val_dice_coef', 'val_loss', 'val_precision',
#        'val_recall'],
#       dtype='object')

# %%
#https://github.com/nikhilroxtomar/Brain-Tumor-Segmentation-in-TensorFlow-2.0

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    smooth = 1.0
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

# %%
model = load_model("C:\\Projects Datasets\\model_details\\unet_4\\model_2.h5",
                   custom_objects={"dice_coef": dice_coef},
                   compile=False)

# %%
import cv2
import numpy as np

# Load image
img_path = "C:\\Projects Datasets\\model_details\\1111.jpg"
image = cv2.imread(img_path)              # BGR format
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB

# Resize to model input size
image_resized = cv2.resize(image, (256, 256))

# Normalize to [0,1]
image_norm = image_resized / 255.0

# Add batch dimension
input_tensor = np.expand_dims(image_norm, axis=0)   # shape (1, 256, 256, 3)

# %%
pred_mask = model.predict(input_tensor)

# Remove batch dimension
pred_mask = pred_mask[0]

# Threshold (convert probabilities to binary mask)
binary_mask = (pred_mask > 0.5).astype(np.uint8)
# Out:
# 1/1 [==============================] - 0s 301ms/step

# %%
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.imshow(image_resized)
plt.title("Input Image")

plt.subplot(1, 2, 2)
plt.imshow(binary_mask.squeeze(), cmap="gray")
plt.title("Predicted Mask")

plt.show()
