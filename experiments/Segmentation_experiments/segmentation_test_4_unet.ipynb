# %%
import os


import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
# from unet import build_unet
from tensorflow.keras.metrics import Precision, Recall
 
import random
 

# from metrics import dice_loss, dice_coef
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
# Out:
# C:\Users\chanu\anaconda3\envs\tensorNewGPU\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
import tensorflow as tf
print(tf.test.is_built_with_cuda())
# Out:
# True

# %%
print(tf.sysconfig.get_build_info())
# Out:
# OrderedDict([('cpu_compiler', 'C:/Program Files (x86)/Microsoft Visual Studio/2019/Community/VC/Tools/MSVC/14.29.30133/bin/HostX64/x64/cl.exe'), ('cuda_compute_capabilities', ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']), ('cuda_version', '64_112'), ('cudart_dll_name', 'cudart64_112.dll'), ('cudnn_dll_name', 'cudnn64_8.dll'), ('cudnn_version', '64_8'), ('is_cuda_build', True), ('is_rocm_build', False), ('is_tensorrt_build', False), ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll'), ('nvcuda_dll_name', 'nvcuda.dll')])

# %%
import tensorflow as tf

print("GPU in use:", tf.test.gpu_device_name())
# Out:
# GPU in use: /device:GPU:0

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    details = tf.config.experimental.get_device_details(gpus[0])
    print(details)
# Out:
# {'device_name': 'NVIDIA GeForce RTX 4050 Laptop GPU', 'compute_capability': (8, 9)}

# %%
gpus=tf.config.list_physical_devices('GPU')
if gpus:
    print('GPU available')
else:
    print('GPU not available')
tf.config.list_physical_devices('GPU')
# Out:
# GPU available
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf

# List logical devices (after setting visible devices)
logical_gpus = tf.config.list_logical_devices('GPU')
print("Logical GPUs:", logical_gpus)
# Out:
# Logical GPUs: [LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
tf.debugging.set_log_device_placement(False)

# %%
H = 256
W = 256

# %%
# Set a global seed
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
from tensorflow.keras import backend as K

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

# def dice_loss(y_true, y_pred):
#     return 1.0 - dice_coef(y_true, y_pred)
def dice_loss(y_true, y_pred):
    smooth = 1.0
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

# %%
# def conv_block(inputs, num_filters):
#     x = Conv2D(num_filters, 3, padding="same")(inputs)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)

#     x = Conv2D(num_filters, 3, padding="same")(x)
#     x = BatchNormalization()(x)
#     x = Activation("relu")(x)

#     return x


from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def conv_block(x, num_filters, dropout_rate=0.0, reg=1e-4):
    x = Conv2D(
        num_filters,
        3,
        padding="same",
        kernel_initializer="he_normal",
        kernel_regularizer=l2(reg)
    )(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    if dropout_rate > 0:
        x = Dropout(dropout_rate)(x)

    x = Conv2D(
        num_filters,
        3,
        padding="same",
        kernel_initializer="he_normal",
        kernel_regularizer=l2(reg)
    )(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    return x


def encoder_block(inputs, num_filters, dropout_rate):
    x = conv_block(inputs, num_filters, dropout_rate)
    p = MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(inputs, skip_features, num_filters, dropout_rate):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters, dropout_rate)
    return x

    
# def decoder_block(inputs, skip_features, num_filters):
#     x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(inputs)
#     x = Concatenate()([x, skip_features])
#     x = conv_block(x, num_filters)
#     return x

# def build_unet(input_shape):
#     inputs = Input(input_shape)

#     s1, p1 = encoder_block(inputs, 64)
#     s2, p2 = encoder_block(p1, 128)
#     s3, p3 = encoder_block(p2, 256)
#     s4, p4 = encoder_block(p3, 512)

#     # print(s1.shape, s2.shape, s3.shape, s4.shape)
#     # print(p1.shape, p2.shape, p3.shape, p4.shape)

#     b1 = conv_block(p4, 1024)

#     d1 = decoder_block(b1, s4, 512)
#     d2 = decoder_block(d1, s3, 256)
#     d3 = decoder_block(d2, s2, 128)
#     d4 = decoder_block(d3, s1, 64)

#     outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

#     model = Model(inputs, outputs, name="UNET")
#     return model
def build_unet(input_shape):
    inputs = Input(input_shape)

    # Encoder (low dropout)
    s1, p1 = encoder_block(inputs, 32, 0.0)
    s2, p2 = encoder_block(p1, 64, 0.1)
    s3, p3 = encoder_block(p2, 128, 0.2)

    # Bottleneck (highest dropout)
    b1 = conv_block(p3, 256, dropout_rate=0.4)

    # Decoder (moderate dropout)
    d1 = decoder_block(b1, s3, 128, 0.2)
    d2 = decoder_block(d1, s2, 64, 0.1)
    d3 = decoder_block(d2, s1, 32, 0.0)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d3)

    model = Model(inputs, outputs, name="UNET_Optimized")
    return model


if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = build_unet(input_shape)
    model.summary()
# Out:
# Model: "UNET_Optimized"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  leaky_re_lu (LeakyReLU)        (None, 256, 256, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['leaky_re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 256, 256, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['leaky_re_lu_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 128, 128, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 64  0           ['leaky_re_lu_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['dropout[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 128, 128, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 128)  0           ['leaky_re_lu_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['dropout_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['leaky_re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 256)  0           ['batch_normalization_6[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 256)  0           ['leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['dropout_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 32, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 128)  131200     ['leaky_re_lu_7[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  295040      ['concatenate[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_8[0][0]']
#
#  dropout_3 (Dropout)            (None, 64, 64, 128)  0           ['leaky_re_lu_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 128)  147584      ['dropout_3[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 64  32832      ['leaky_re_lu_9[0][0]']
#  spose)                         )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_1[0][0]',
#                                 8)                                'leaky_re_lu_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 128, 128, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  dropout_4 (Dropout)            (None, 128, 128, 64  0           ['leaky_re_lu_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_4[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 128, 128, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 32  8224       ['leaky_re_lu_11[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'leaky_re_lu_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 256, 256, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 32  9248        ['leaky_re_lu_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 256, 256, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 1)  33          ['leaky_re_lu_13[0][0]']
#
# ==================================================================================================
# Total params: 1,931,233
# Trainable params: 1,928,417
# Non-trainable params: 2,816
# __________________________________________________________________________________________________

# %%
# def read_mask(path):
#     x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
#     if x is None:
#         raise ValueError(f"Mask not found or unreadable: {path}")
#     x = cv2.resize(x, (W, H))
#     return x
# print(read_mask("C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\masks"))

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

# def load_dataset(path, split=0.2):
#     images = sorted(glob(os.path.join(path, "images", "*.png")))
#     masks = sorted(glob(os.path.join(path, "masks", "*.png")))

#     split_size = int(len(images) * split)

#     train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
#     train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

#     train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
#     train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

#     return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)
def load_dataset(path, split=0.2, max_samples=None):
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks  = sorted(glob(os.path.join(path, "masks", "*.png")))

    assert len(images) == len(masks), "Images and masks count mismatch"

    # 🔹 Limit dataset size
    if max_samples is not None:
        images = images[:max_samples]
        masks  = masks[:max_samples]

    # 🔹 Train / temp split
    train_x, temp_x, train_y, temp_y = train_test_split(
        images, masks,
        test_size=2 * split,
        random_state=42,
        shuffle=True
    )

    # 🔹 Validation / Test split
    valid_x, test_x, valid_y, test_y = train_test_split(
        temp_x, temp_y,
        test_size=0.5,
        random_state=42
    )

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (h, w)
    x = cv2.resize(x, (W, H))   ## (h, w)
    x = x / 255.0               ## (h, w)
    x = x.astype(np.float32)    ## (h, w)
    x = np.expand_dims(x, axis=-1)## (h, w, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 12
    lr = 1e-4
    num_epochs = 100
    model_path = os.path.join("C:\\Projects Datasets\\model_details\\unet_2", "model_2.h5")
    csv_path = os.path.join("C:\\Projects Datasets\\model_details\\unet_2", "log.csv")

    """ Dataset """
    # dataset_path = "C:\\Projects Datasets\\Segmentation_1\\Segmentation_filtered"
    dataset_path="C:\Projects Datasets\Segmentation_1\Segmentation"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path,0.2,1200)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test : {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
    test_dataset  = tf_dataset(test_x, test_y, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    # model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=["accuracy", dice_coef])
    model.compile( loss=dice_loss, optimizer=Adam(lr), metrics=["accuracy", dice_coef, Precision(name="precision"), Recall(name="recall")] )

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]

    history = model.fit(
        train_dataset,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 720 - 720
# Valid: 240 - 240
# Test : 240 - 240
# Epoch 1/100
# 60/60 [==============================] - ETA: 0s - loss: 1.2176 - accuracy: 0.8788 - dice_coef: 0.0420 - precision: 0.0452 - recall: 0.4223
# Epoch 1: val_loss improved from inf to 1.20995, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 34s 357ms/step - loss: 1.2176 - accuracy: 0.8788 - dice_coef: 0.0420 - precision: 0.0452 - recall: 0.4223 - val_loss: 1.2099 - val_accuracy: 0.8934 - val_dice_coef: 0.0286 - val_precision: 0.0472 - val_recall: 0.4099 - lr: 1.0000e-04
# Epoch 2/100
# 60/60 [==============================] - ETA: 0s - loss: 1.1417 - accuracy: 0.8722 - dice_coef: 0.0844 - precision: 0.0751 - recall: 0.7936
# Epoch 2: val_loss improved from 1.20995 to 1.18819, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 1.1417 - accuracy: 0.8722 - dice_coef: 0.0844 - precision: 0.0751 - recall: 0.7936 - val_loss: 1.1882 - val_accuracy: 0.7923 - val_dice_coef: 0.0294 - val_precision: 0.0241 - val_recall: 0.4109 - lr: 1.0000e-04
# Epoch 3/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0878 - accuracy: 0.9406 - dice_coef: 0.1250 - precision: 0.1516 - recall: 0.7860
# Epoch 3: val_loss improved from 1.18819 to 1.17133, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 1.0878 - accuracy: 0.9406 - dice_coef: 0.1250 - precision: 0.1516 - recall: 0.7860 - val_loss: 1.1713 - val_accuracy: 0.7870 - val_dice_coef: 0.0372 - val_precision: 0.0267 - val_recall: 0.4707 - lr: 1.0000e-04
# Epoch 4/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0440 - accuracy: 0.9631 - dice_coef: 0.1614 - precision: 0.2266 - recall: 0.7671
# Epoch 4: val_loss improved from 1.17133 to 1.15415, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 1.0440 - accuracy: 0.9631 - dice_coef: 0.1614 - precision: 0.2266 - recall: 0.7671 - val_loss: 1.1541 - val_accuracy: 0.8052 - val_dice_coef: 0.0484 - val_precision: 0.0347 - val_recall: 0.5653 - lr: 1.0000e-04
# Epoch 5/100
# 60/60 [==============================] - ETA: 0s - loss: 1.0087 - accuracy: 0.9730 - dice_coef: 0.1915 - precision: 0.2930 - recall: 0.7587
# Epoch 5: val_loss improved from 1.15415 to 1.11310, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 346ms/step - loss: 1.0087 - accuracy: 0.9730 - dice_coef: 0.1915 - precision: 0.2930 - recall: 0.7587 - val_loss: 1.1131 - val_accuracy: 0.9247 - val_dice_coef: 0.0849 - val_precision: 0.0838 - val_recall: 0.5262 - lr: 1.0000e-04
# Epoch 6/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.9790 - dice_coef: 0.2222 - precision: 0.3575 - recall: 0.7553
# Epoch 6: val_loss improved from 1.11310 to 1.05195, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.9740 - accuracy: 0.9790 - dice_coef: 0.2222 - precision: 0.3575 - recall: 0.7553 - val_loss: 1.0520 - val_accuracy: 0.9762 - val_dice_coef: 0.1426 - val_precision: 0.2527 - val_recall: 0.4849 - lr: 1.0000e-04
# Epoch 7/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9483 - accuracy: 0.9808 - dice_coef: 0.2449 - precision: 0.3815 - recall: 0.7410
# Epoch 7: val_loss improved from 1.05195 to 1.01032, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.9483 - accuracy: 0.9808 - dice_coef: 0.2449 - precision: 0.3815 - recall: 0.7410 - val_loss: 1.0103 - val_accuracy: 0.9812 - val_dice_coef: 0.1815 - val_precision: 0.3412 - val_recall: 0.5638 - lr: 1.0000e-04
# Epoch 8/100
# 60/60 [==============================] - ETA: 0s - loss: 0.9103 - accuracy: 0.9841 - dice_coef: 0.2803 - precision: 0.4409 - recall: 0.7488
# Epoch 8: val_loss improved from 1.01032 to 1.00058, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.9103 - accuracy: 0.9841 - dice_coef: 0.2803 - precision: 0.4409 - recall: 0.7488 - val_loss: 1.0006 - val_accuracy: 0.9854 - val_dice_coef: 0.1889 - val_precision: 0.4209 - val_recall: 0.4885 - lr: 1.0000e-04
# Epoch 9/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8708 - accuracy: 0.9862 - dice_coef: 0.3176 - precision: 0.4887 - recall: 0.7579
# Epoch 9: val_loss improved from 1.00058 to 0.98258, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.8708 - accuracy: 0.9862 - dice_coef: 0.3176 - precision: 0.4887 - recall: 0.7579 - val_loss: 0.9826 - val_accuracy: 0.9901 - val_dice_coef: 0.2048 - val_precision: 0.6613 - val_recall: 0.4124 - lr: 1.0000e-04
# Epoch 10/100
# 60/60 [==============================] - ETA: 0s - loss: 0.8289 - accuracy: 0.9886 - dice_coef: 0.3576 - precision: 0.5528 - recall: 0.7587
# Epoch 10: val_loss improved from 0.98258 to 0.90833, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.8289 - accuracy: 0.9886 - dice_coef: 0.3576 - precision: 0.5528 - recall: 0.7587 - val_loss: 0.9083 - val_accuracy: 0.9901 - val_dice_coef: 0.2773 - val_precision: 0.6190 - val_recall: 0.5504 - lr: 1.0000e-04
# Epoch 11/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7956 - accuracy: 0.9891 - dice_coef: 0.3893 - precision: 0.5691 - recall: 0.7583
# Epoch 11: val_loss did not improve from 0.90833
# 60/60 [==============================] - 21s 344ms/step - loss: 0.7956 - accuracy: 0.9891 - dice_coef: 0.3893 - precision: 0.5691 - recall: 0.7583 - val_loss: 0.9363 - val_accuracy: 0.9891 - val_dice_coef: 0.2478 - val_precision: 0.5779 - val_recall: 0.4323 - lr: 1.0000e-04
# Epoch 12/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.9900 - dice_coef: 0.4197 - precision: 0.6022 - recall: 0.7469
# Epoch 12: val_loss improved from 0.90833 to 0.84300, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 351ms/step - loss: 0.7637 - accuracy: 0.9900 - dice_coef: 0.4197 - precision: 0.6022 - recall: 0.7469 - val_loss: 0.8430 - val_accuracy: 0.9906 - val_dice_coef: 0.3398 - val_precision: 0.6339 - val_recall: 0.5891 - lr: 1.0000e-04
# Epoch 13/100
# 60/60 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.9907 - dice_coef: 0.4491 - precision: 0.6337 - recall: 0.7336
# Epoch 13: val_loss did not improve from 0.84300
# 60/60 [==============================] - 21s 345ms/step - loss: 0.7331 - accuracy: 0.9907 - dice_coef: 0.4491 - precision: 0.6337 - recall: 0.7336 - val_loss: 0.8556 - val_accuracy: 0.9903 - val_dice_coef: 0.3260 - val_precision: 0.6513 - val_recall: 0.4695 - lr: 1.0000e-04
# Epoch 14/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6831 - accuracy: 0.9918 - dice_coef: 0.4980 - precision: 0.6783 - recall: 0.7623
# Epoch 14: val_loss improved from 0.84300 to 0.82185, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.6831 - accuracy: 0.9918 - dice_coef: 0.4980 - precision: 0.6783 - recall: 0.7623 - val_loss: 0.8219 - val_accuracy: 0.9921 - val_dice_coef: 0.3587 - val_precision: 0.8165 - val_recall: 0.4664 - lr: 1.0000e-04
# Epoch 15/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6520 - accuracy: 0.9923 - dice_coef: 0.5280 - precision: 0.7004 - recall: 0.7614
# Epoch 15: val_loss improved from 0.82185 to 0.74866, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.6520 - accuracy: 0.9923 - dice_coef: 0.5280 - precision: 0.7004 - recall: 0.7614 - val_loss: 0.7487 - val_accuracy: 0.9926 - val_dice_coef: 0.4309 - val_precision: 0.7823 - val_recall: 0.5644 - lr: 1.0000e-04
# Epoch 16/100
# 60/60 [==============================] - ETA: 0s - loss: 0.6155 - accuracy: 0.9931 - dice_coef: 0.5635 - precision: 0.7404 - recall: 0.7674
# Epoch 16: val_loss improved from 0.74866 to 0.68984, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.6155 - accuracy: 0.9931 - dice_coef: 0.5635 - precision: 0.7404 - recall: 0.7674 - val_loss: 0.6898 - val_accuracy: 0.9931 - val_dice_coef: 0.4887 - val_precision: 0.7941 - val_recall: 0.6247 - lr: 1.0000e-04
# Epoch 17/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.9930 - dice_coef: 0.5788 - precision: 0.7364 - recall: 0.7557
# Epoch 17: val_loss did not improve from 0.68984
# 60/60 [==============================] - 21s 344ms/step - loss: 0.5994 - accuracy: 0.9930 - dice_coef: 0.5788 - precision: 0.7364 - recall: 0.7557 - val_loss: 0.7304 - val_accuracy: 0.9923 - val_dice_coef: 0.4473 - val_precision: 0.7946 - val_recall: 0.5184 - lr: 1.0000e-04
# Epoch 18/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5805 - accuracy: 0.9930 - dice_coef: 0.5969 - precision: 0.7402 - recall: 0.7557
# Epoch 18: val_loss improved from 0.68984 to 0.65528, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.5805 - accuracy: 0.9930 - dice_coef: 0.5969 - precision: 0.7402 - recall: 0.7557 - val_loss: 0.6553 - val_accuracy: 0.9922 - val_dice_coef: 0.5217 - val_precision: 0.6970 - val_recall: 0.6874 - lr: 1.0000e-04
# Epoch 19/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5494 - accuracy: 0.9937 - dice_coef: 0.6272 - precision: 0.7743 - recall: 0.7626
# Epoch 19: val_loss improved from 0.65528 to 0.62679, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.5494 - accuracy: 0.9937 - dice_coef: 0.6272 - precision: 0.7743 - recall: 0.7626 - val_loss: 0.6268 - val_accuracy: 0.9924 - val_dice_coef: 0.5495 - val_precision: 0.7004 - val_recall: 0.7041 - lr: 1.0000e-04
# Epoch 20/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5198 - accuracy: 0.9941 - dice_coef: 0.6561 - precision: 0.7908 - recall: 0.7782
# Epoch 20: val_loss improved from 0.62679 to 0.61688, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.5198 - accuracy: 0.9941 - dice_coef: 0.6561 - precision: 0.7908 - recall: 0.7782 - val_loss: 0.6169 - val_accuracy: 0.9922 - val_dice_coef: 0.5587 - val_precision: 0.6957 - val_recall: 0.6831 - lr: 1.0000e-04
# Epoch 21/100
# 60/60 [==============================] - ETA: 0s - loss: 0.5091 - accuracy: 0.9941 - dice_coef: 0.6662 - precision: 0.7966 - recall: 0.7707
# Epoch 21: val_loss did not improve from 0.61688
# 60/60 [==============================] - 21s 347ms/step - loss: 0.5091 - accuracy: 0.9941 - dice_coef: 0.6662 - precision: 0.7966 - recall: 0.7707 - val_loss: 0.6176 - val_accuracy: 0.9931 - val_dice_coef: 0.5573 - val_precision: 0.8008 - val_recall: 0.6003 - lr: 1.0000e-04
# Epoch 22/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.9940 - dice_coef: 0.6756 - precision: 0.7953 - recall: 0.7666
# Epoch 22: val_loss did not improve from 0.61688
# 60/60 [==============================] - 21s 346ms/step - loss: 0.4991 - accuracy: 0.9940 - dice_coef: 0.6756 - precision: 0.7953 - recall: 0.7666 - val_loss: 0.7211 - val_accuracy: 0.9917 - val_dice_coef: 0.4532 - val_precision: 0.8312 - val_recall: 0.4066 - lr: 1.0000e-04
# Epoch 23/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4838 - accuracy: 0.9943 - dice_coef: 0.6902 - precision: 0.8123 - recall: 0.7624
# Epoch 23: val_loss improved from 0.61688 to 0.60548, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 350ms/step - loss: 0.4838 - accuracy: 0.9943 - dice_coef: 0.6902 - precision: 0.8123 - recall: 0.7624 - val_loss: 0.6055 - val_accuracy: 0.9930 - val_dice_coef: 0.5682 - val_precision: 0.8270 - val_recall: 0.5661 - lr: 1.0000e-04
# Epoch 24/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4580 - accuracy: 0.9947 - dice_coef: 0.7155 - precision: 0.8309 - recall: 0.7810
# Epoch 24: val_loss improved from 0.60548 to 0.56612, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 352ms/step - loss: 0.4580 - accuracy: 0.9947 - dice_coef: 0.7155 - precision: 0.8309 - recall: 0.7810 - val_loss: 0.5661 - val_accuracy: 0.9927 - val_dice_coef: 0.6070 - val_precision: 0.7451 - val_recall: 0.6583 - lr: 1.0000e-04
# Epoch 25/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.9949 - dice_coef: 0.7262 - precision: 0.8414 - recall: 0.7783
# Epoch 25: val_loss improved from 0.56612 to 0.55263, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 350ms/step - loss: 0.4466 - accuracy: 0.9949 - dice_coef: 0.7262 - precision: 0.8414 - recall: 0.7783 - val_loss: 0.5526 - val_accuracy: 0.9933 - val_dice_coef: 0.6199 - val_precision: 0.7915 - val_recall: 0.6452 - lr: 1.0000e-04
# Epoch 26/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.9951 - dice_coef: 0.7427 - precision: 0.8537 - recall: 0.7854
# Epoch 26: val_loss did not improve from 0.55263
# 60/60 [==============================] - 21s 345ms/step - loss: 0.4296 - accuracy: 0.9951 - dice_coef: 0.7427 - precision: 0.8537 - recall: 0.7854 - val_loss: 0.5564 - val_accuracy: 0.9935 - val_dice_coef: 0.6155 - val_precision: 0.8652 - val_recall: 0.5741 - lr: 1.0000e-04
# Epoch 27/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4289 - accuracy: 0.9950 - dice_coef: 0.7427 - precision: 0.8509 - recall: 0.7761
# Epoch 27: val_loss improved from 0.55263 to 0.52059, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.4289 - accuracy: 0.9950 - dice_coef: 0.7427 - precision: 0.8509 - recall: 0.7761 - val_loss: 0.5206 - val_accuracy: 0.9932 - val_dice_coef: 0.6508 - val_precision: 0.7561 - val_recall: 0.6912 - lr: 1.0000e-04
# Epoch 28/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4165 - accuracy: 0.9951 - dice_coef: 0.7546 - precision: 0.8541 - recall: 0.7850
# Epoch 28: val_loss did not improve from 0.52059
# 60/60 [==============================] - 21s 342ms/step - loss: 0.4165 - accuracy: 0.9951 - dice_coef: 0.7546 - precision: 0.8541 - recall: 0.7850 - val_loss: 0.5226 - val_accuracy: 0.9935 - val_dice_coef: 0.6483 - val_precision: 0.8034 - val_recall: 0.6450 - lr: 1.0000e-04
# Epoch 29/100
# 60/60 [==============================] - ETA: 0s - loss: 0.4104 - accuracy: 0.9951 - dice_coef: 0.7603 - precision: 0.8562 - recall: 0.7863
# Epoch 29: val_loss improved from 0.52059 to 0.51433, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.4104 - accuracy: 0.9951 - dice_coef: 0.7603 - precision: 0.8562 - recall: 0.7863 - val_loss: 0.5143 - val_accuracy: 0.9933 - val_dice_coef: 0.6560 - val_precision: 0.7708 - val_recall: 0.6695 - lr: 1.0000e-04
# Epoch 30/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3932 - accuracy: 0.9954 - dice_coef: 0.7770 - precision: 0.8648 - recall: 0.7998
# Epoch 30: val_loss improved from 0.51433 to 0.47832, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.3932 - accuracy: 0.9954 - dice_coef: 0.7770 - precision: 0.8648 - recall: 0.7998 - val_loss: 0.4783 - val_accuracy: 0.9939 - val_dice_coef: 0.6915 - val_precision: 0.7956 - val_recall: 0.7115 - lr: 1.0000e-04
# Epoch 31/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.9955 - dice_coef: 0.7839 - precision: 0.8776 - recall: 0.7962
# Epoch 31: val_loss did not improve from 0.47832
# 60/60 [==============================] - 21s 345ms/step - loss: 0.3857 - accuracy: 0.9955 - dice_coef: 0.7839 - precision: 0.8776 - recall: 0.7962 - val_loss: 0.4938 - val_accuracy: 0.9935 - val_dice_coef: 0.6755 - val_precision: 0.7904 - val_recall: 0.6749 - lr: 1.0000e-04
# Epoch 32/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3751 - accuracy: 0.9957 - dice_coef: 0.7940 - precision: 0.8803 - recall: 0.8049
# Epoch 32: val_loss did not improve from 0.47832
# 60/60 [==============================] - 21s 343ms/step - loss: 0.3751 - accuracy: 0.9957 - dice_coef: 0.7940 - precision: 0.8803 - recall: 0.8049 - val_loss: 0.4818 - val_accuracy: 0.9937 - val_dice_coef: 0.6869 - val_precision: 0.7884 - val_recall: 0.6936 - lr: 1.0000e-04
# Epoch 33/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3716 - accuracy: 0.9957 - dice_coef: 0.7969 - precision: 0.8829 - recall: 0.8026
# Epoch 33: val_loss improved from 0.47832 to 0.47687, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.3716 - accuracy: 0.9957 - dice_coef: 0.7969 - precision: 0.8829 - recall: 0.8026 - val_loss: 0.4769 - val_accuracy: 0.9936 - val_dice_coef: 0.6914 - val_precision: 0.7790 - val_recall: 0.7032 - lr: 1.0000e-04
# Epoch 34/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3585 - accuracy: 0.9959 - dice_coef: 0.8095 - precision: 0.8927 - recall: 0.8135
# Epoch 34: val_loss improved from 0.47687 to 0.47028, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.3585 - accuracy: 0.9959 - dice_coef: 0.8095 - precision: 0.8927 - recall: 0.8135 - val_loss: 0.4703 - val_accuracy: 0.9942 - val_dice_coef: 0.6975 - val_precision: 0.8655 - val_recall: 0.6465 - lr: 1.0000e-04
# Epoch 35/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3548 - accuracy: 0.9959 - dice_coef: 0.8126 - precision: 0.8931 - recall: 0.8126
# Epoch 35: val_loss improved from 0.47028 to 0.46261, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.3548 - accuracy: 0.9959 - dice_coef: 0.8126 - precision: 0.8931 - recall: 0.8126 - val_loss: 0.4626 - val_accuracy: 0.9940 - val_dice_coef: 0.7046 - val_precision: 0.8189 - val_recall: 0.6845 - lr: 1.0000e-04
# Epoch 36/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3490 - accuracy: 0.9960 - dice_coef: 0.8180 - precision: 0.8996 - recall: 0.8128
# Epoch 36: val_loss did not improve from 0.46261
# 60/60 [==============================] - 21s 345ms/step - loss: 0.3490 - accuracy: 0.9960 - dice_coef: 0.8180 - precision: 0.8996 - recall: 0.8128 - val_loss: 0.4658 - val_accuracy: 0.9942 - val_dice_coef: 0.7009 - val_precision: 0.8651 - val_recall: 0.6393 - lr: 1.0000e-04
# Epoch 37/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.9958 - dice_coef: 0.8136 - precision: 0.8901 - recall: 0.8057
# Epoch 37: val_loss did not improve from 0.46261
# 60/60 [==============================] - 21s 345ms/step - loss: 0.3528 - accuracy: 0.9958 - dice_coef: 0.8136 - precision: 0.8901 - recall: 0.8057 - val_loss: 0.5952 - val_accuracy: 0.9881 - val_dice_coef: 0.5710 - val_precision: 0.5178 - val_recall: 0.6999 - lr: 1.0000e-04
# Epoch 38/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.9961 - dice_coef: 0.8249 - precision: 0.9023 - recall: 0.8149
# Epoch 38: val_loss improved from 0.46261 to 0.46004, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 352ms/step - loss: 0.3411 - accuracy: 0.9961 - dice_coef: 0.8249 - precision: 0.9023 - recall: 0.8149 - val_loss: 0.4600 - val_accuracy: 0.9939 - val_dice_coef: 0.7057 - val_precision: 0.8115 - val_recall: 0.6785 - lr: 1.0000e-04
# Epoch 39/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.9961 - dice_coef: 0.8278 - precision: 0.9010 - recall: 0.8181
# Epoch 39: val_loss improved from 0.46004 to 0.44146, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 350ms/step - loss: 0.3377 - accuracy: 0.9961 - dice_coef: 0.8278 - precision: 0.9010 - recall: 0.8181 - val_loss: 0.4415 - val_accuracy: 0.9938 - val_dice_coef: 0.7238 - val_precision: 0.7701 - val_recall: 0.7432 - lr: 1.0000e-04
# Epoch 40/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.9963 - dice_coef: 0.8386 - precision: 0.9108 - recall: 0.8267
# Epoch 40: val_loss did not improve from 0.44146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.3264 - accuracy: 0.9963 - dice_coef: 0.8386 - precision: 0.9108 - recall: 0.8267 - val_loss: 0.4429 - val_accuracy: 0.9943 - val_dice_coef: 0.7219 - val_precision: 0.8606 - val_recall: 0.6651 - lr: 1.0000e-04
# Epoch 41/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.9962 - dice_coef: 0.8351 - precision: 0.9017 - recall: 0.8252
# Epoch 41: val_loss improved from 0.44146 to 0.43099, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 352ms/step - loss: 0.3294 - accuracy: 0.9962 - dice_coef: 0.8351 - precision: 0.9017 - recall: 0.8252 - val_loss: 0.4310 - val_accuracy: 0.9944 - val_dice_coef: 0.7333 - val_precision: 0.8467 - val_recall: 0.6929 - lr: 1.0000e-04
# Epoch 42/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.9964 - dice_coef: 0.8445 - precision: 0.9153 - recall: 0.8278
# Epoch 42: val_loss did not improve from 0.43099
# 60/60 [==============================] - 21s 343ms/step - loss: 0.3195 - accuracy: 0.9964 - dice_coef: 0.8445 - precision: 0.9153 - recall: 0.8278 - val_loss: 0.4495 - val_accuracy: 0.9940 - val_dice_coef: 0.7142 - val_precision: 0.8252 - val_recall: 0.6736 - lr: 1.0000e-04
# Epoch 43/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3144 - accuracy: 0.9964 - dice_coef: 0.8491 - precision: 0.9135 - recall: 0.8345
# Epoch 43: val_loss did not improve from 0.43099
# 60/60 [==============================] - 21s 345ms/step - loss: 0.3144 - accuracy: 0.9964 - dice_coef: 0.8491 - precision: 0.9135 - recall: 0.8345 - val_loss: 0.4345 - val_accuracy: 0.9942 - val_dice_coef: 0.7288 - val_precision: 0.8354 - val_recall: 0.6887 - lr: 1.0000e-04
# Epoch 44/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.9966 - dice_coef: 0.8557 - precision: 0.9208 - recall: 0.8391
# Epoch 44: val_loss improved from 0.43099 to 0.41947, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.3073 - accuracy: 0.9966 - dice_coef: 0.8557 - precision: 0.9208 - recall: 0.8391 - val_loss: 0.4195 - val_accuracy: 0.9945 - val_dice_coef: 0.7433 - val_precision: 0.8410 - val_recall: 0.7069 - lr: 1.0000e-04
# Epoch 45/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.9966 - dice_coef: 0.8567 - precision: 0.9193 - recall: 0.8387
# Epoch 45: val_loss did not improve from 0.41947
# 60/60 [==============================] - 21s 347ms/step - loss: 0.3057 - accuracy: 0.9966 - dice_coef: 0.8567 - precision: 0.9193 - recall: 0.8387 - val_loss: 0.4419 - val_accuracy: 0.9936 - val_dice_coef: 0.7204 - val_precision: 0.7716 - val_recall: 0.7201 - lr: 1.0000e-04
# Epoch 46/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9965 - dice_coef: 0.8551 - precision: 0.9185 - recall: 0.8351
# Epoch 46: val_loss did not improve from 0.41947
# 60/60 [==============================] - 21s 346ms/step - loss: 0.3069 - accuracy: 0.9965 - dice_coef: 0.8551 - precision: 0.9185 - recall: 0.8351 - val_loss: 0.4270 - val_accuracy: 0.9937 - val_dice_coef: 0.7347 - val_precision: 0.7509 - val_recall: 0.7680 - lr: 1.0000e-04
# Epoch 47/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.9965 - dice_coef: 0.8535 - precision: 0.9133 - recall: 0.8350
# Epoch 47: val_loss did not improve from 0.41947
# 60/60 [==============================] - 21s 346ms/step - loss: 0.3081 - accuracy: 0.9965 - dice_coef: 0.8535 - precision: 0.9133 - recall: 0.8350 - val_loss: 0.4626 - val_accuracy: 0.9923 - val_dice_coef: 0.6987 - val_precision: 0.6739 - val_recall: 0.7774 - lr: 1.0000e-04
# Epoch 48/100
# 60/60 [==============================] - ETA: 0s - loss: 0.3013 - accuracy: 0.9966 - dice_coef: 0.8598 - precision: 0.9214 - recall: 0.8385
# Epoch 48: val_loss did not improve from 0.41947
# 60/60 [==============================] - 21s 343ms/step - loss: 0.3013 - accuracy: 0.9966 - dice_coef: 0.8598 - precision: 0.9214 - recall: 0.8385 - val_loss: 0.4279 - val_accuracy: 0.9943 - val_dice_coef: 0.7329 - val_precision: 0.8599 - val_recall: 0.6705 - lr: 1.0000e-04
# Epoch 49/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.9967 - dice_coef: 0.8660 - precision: 0.9233 - recall: 0.8456
# Epoch 49: val_loss did not improve from 0.41947
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2946 - accuracy: 0.9967 - dice_coef: 0.8660 - precision: 0.9233 - recall: 0.8456 - val_loss: 0.4224 - val_accuracy: 0.9941 - val_dice_coef: 0.7379 - val_precision: 0.8122 - val_recall: 0.7071 - lr: 1.0000e-04
# Epoch 50/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.9969 - dice_coef: 0.8730 - precision: 0.9279 - recall: 0.8540
# Epoch 50: val_loss improved from 0.41947 to 0.41498, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 350ms/step - loss: 0.2873 - accuracy: 0.9969 - dice_coef: 0.8730 - precision: 0.9279 - recall: 0.8540 - val_loss: 0.4150 - val_accuracy: 0.9946 - val_dice_coef: 0.7453 - val_precision: 0.8797 - val_recall: 0.6686 - lr: 1.0000e-05
# Epoch 51/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2818 - accuracy: 0.9970 - dice_coef: 0.8785 - precision: 0.9347 - recall: 0.8588
# Epoch 51: val_loss improved from 0.41498 to 0.41179, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.2818 - accuracy: 0.9970 - dice_coef: 0.8785 - precision: 0.9347 - recall: 0.8588 - val_loss: 0.4118 - val_accuracy: 0.9946 - val_dice_coef: 0.7485 - val_precision: 0.8846 - val_recall: 0.6699 - lr: 1.0000e-05
# Epoch 52/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.9970 - dice_coef: 0.8803 - precision: 0.9351 - recall: 0.8613
# Epoch 52: val_loss improved from 0.41179 to 0.41129, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 351ms/step - loss: 0.2800 - accuracy: 0.9970 - dice_coef: 0.8803 - precision: 0.9351 - recall: 0.8613 - val_loss: 0.4113 - val_accuracy: 0.9947 - val_dice_coef: 0.7489 - val_precision: 0.8913 - val_recall: 0.6659 - lr: 1.0000e-05
# Epoch 53/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.9970 - dice_coef: 0.8795 - precision: 0.9350 - recall: 0.8600
# Epoch 53: val_loss improved from 0.41129 to 0.40618, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.2806 - accuracy: 0.9970 - dice_coef: 0.8795 - precision: 0.9350 - recall: 0.8600 - val_loss: 0.4062 - val_accuracy: 0.9947 - val_dice_coef: 0.7540 - val_precision: 0.8877 - val_recall: 0.6763 - lr: 1.0000e-05
# Epoch 54/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2772 - accuracy: 0.9971 - dice_coef: 0.8829 - precision: 0.9385 - recall: 0.8634
# Epoch 54: val_loss did not improve from 0.40618
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2772 - accuracy: 0.9971 - dice_coef: 0.8829 - precision: 0.9385 - recall: 0.8634 - val_loss: 0.4084 - val_accuracy: 0.9947 - val_dice_coef: 0.7517 - val_precision: 0.8898 - val_recall: 0.6714 - lr: 1.0000e-05
# Epoch 55/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.9971 - dice_coef: 0.8824 - precision: 0.9349 - recall: 0.8660
# Epoch 55: val_loss improved from 0.40618 to 0.40509, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.2776 - accuracy: 0.9971 - dice_coef: 0.8824 - precision: 0.9349 - recall: 0.8660 - val_loss: 0.4051 - val_accuracy: 0.9947 - val_dice_coef: 0.7549 - val_precision: 0.8870 - val_recall: 0.6781 - lr: 1.0000e-05
# Epoch 56/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2791 - accuracy: 0.9970 - dice_coef: 0.8809 - precision: 0.9368 - recall: 0.8609
# Epoch 56: val_loss did not improve from 0.40509
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2791 - accuracy: 0.9970 - dice_coef: 0.8809 - precision: 0.9368 - recall: 0.8609 - val_loss: 0.4069 - val_accuracy: 0.9947 - val_dice_coef: 0.7530 - val_precision: 0.8930 - val_recall: 0.6718 - lr: 1.0000e-05
# Epoch 57/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.9971 - dice_coef: 0.8823 - precision: 0.9380 - recall: 0.8629
# Epoch 57: val_loss did not improve from 0.40509
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2776 - accuracy: 0.9971 - dice_coef: 0.8823 - precision: 0.9380 - recall: 0.8629 - val_loss: 0.4089 - val_accuracy: 0.9948 - val_dice_coef: 0.7510 - val_precision: 0.9018 - val_recall: 0.6631 - lr: 1.0000e-05
# Epoch 58/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.9971 - dice_coef: 0.8821 - precision: 0.9358 - recall: 0.8637
# Epoch 58: val_loss did not improve from 0.40509
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2778 - accuracy: 0.9971 - dice_coef: 0.8821 - precision: 0.9358 - recall: 0.8637 - val_loss: 0.4065 - val_accuracy: 0.9948 - val_dice_coef: 0.7533 - val_precision: 0.9049 - val_recall: 0.6633 - lr: 1.0000e-05
# Epoch 59/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2765 - accuracy: 0.9971 - dice_coef: 0.8833 - precision: 0.9382 - recall: 0.8634
# Epoch 59: val_loss did not improve from 0.40509
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2765 - accuracy: 0.9971 - dice_coef: 0.8833 - precision: 0.9382 - recall: 0.8634 - val_loss: 0.4066 - val_accuracy: 0.9947 - val_dice_coef: 0.7531 - val_precision: 0.8942 - val_recall: 0.6700 - lr: 1.0000e-05
# Epoch 60/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.9971 - dice_coef: 0.8842 - precision: 0.9388 - recall: 0.8646
# Epoch 60: val_loss did not improve from 0.40509
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 60/60 [==============================] - 21s 343ms/step - loss: 0.2755 - accuracy: 0.9971 - dice_coef: 0.8842 - precision: 0.9388 - recall: 0.8646 - val_loss: 0.4084 - val_accuracy: 0.9947 - val_dice_coef: 0.7514 - val_precision: 0.8950 - val_recall: 0.6669 - lr: 1.0000e-05
# Epoch 61/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.9971 - dice_coef: 0.8837 - precision: 0.9405 - recall: 0.8612
# Epoch 61: val_loss did not improve from 0.40509
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2760 - accuracy: 0.9971 - dice_coef: 0.8837 - precision: 0.9405 - recall: 0.8612 - val_loss: 0.4060 - val_accuracy: 0.9947 - val_dice_coef: 0.7537 - val_precision: 0.8917 - val_recall: 0.6728 - lr: 1.0000e-06
# Epoch 62/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2730 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9411 - recall: 0.8670
# Epoch 62: val_loss improved from 0.40509 to 0.40447, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 350ms/step - loss: 0.2730 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9411 - recall: 0.8670 - val_loss: 0.4045 - val_accuracy: 0.9948 - val_dice_coef: 0.7552 - val_precision: 0.8908 - val_recall: 0.6759 - lr: 1.0000e-06
# Epoch 63/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.9972 - dice_coef: 0.8861 - precision: 0.9409 - recall: 0.8657
# Epoch 63: val_loss improved from 0.40447 to 0.40362, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 350ms/step - loss: 0.2736 - accuracy: 0.9972 - dice_coef: 0.8861 - precision: 0.9409 - recall: 0.8657 - val_loss: 0.4036 - val_accuracy: 0.9948 - val_dice_coef: 0.7561 - val_precision: 0.8908 - val_recall: 0.6773 - lr: 1.0000e-06
# Epoch 64/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.9972 - dice_coef: 0.8871 - precision: 0.9419 - recall: 0.8674
# Epoch 64: val_loss improved from 0.40362 to 0.40276, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.2726 - accuracy: 0.9972 - dice_coef: 0.8871 - precision: 0.9419 - recall: 0.8674 - val_loss: 0.4028 - val_accuracy: 0.9948 - val_dice_coef: 0.7569 - val_precision: 0.8888 - val_recall: 0.6801 - lr: 1.0000e-06
# Epoch 65/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.9972 - dice_coef: 0.8866 - precision: 0.9405 - recall: 0.8673
# Epoch 65: val_loss improved from 0.40276 to 0.40226, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 348ms/step - loss: 0.2731 - accuracy: 0.9972 - dice_coef: 0.8866 - precision: 0.9405 - recall: 0.8673 - val_loss: 0.4023 - val_accuracy: 0.9948 - val_dice_coef: 0.7574 - val_precision: 0.8890 - val_recall: 0.6809 - lr: 1.0000e-06
# Epoch 66/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9410 - recall: 0.8688
# Epoch 66: val_loss improved from 0.40226 to 0.40223, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9410 - recall: 0.8688 - val_loss: 0.4022 - val_accuracy: 0.9948 - val_dice_coef: 0.7574 - val_precision: 0.8909 - val_recall: 0.6795 - lr: 1.0000e-06
# Epoch 67/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.9972 - dice_coef: 0.8866 - precision: 0.9404 - recall: 0.8680
# Epoch 67: val_loss did not improve from 0.40223
# 60/60 [==============================] - 21s 343ms/step - loss: 0.2731 - accuracy: 0.9972 - dice_coef: 0.8866 - precision: 0.9404 - recall: 0.8680 - val_loss: 0.4024 - val_accuracy: 0.9948 - val_dice_coef: 0.7573 - val_precision: 0.8915 - val_recall: 0.6786 - lr: 1.0000e-06
# Epoch 68/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9435 - recall: 0.8662
# Epoch 68: val_loss did not improve from 0.40223
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9435 - recall: 0.8662 - val_loss: 0.4024 - val_accuracy: 0.9948 - val_dice_coef: 0.7573 - val_precision: 0.8919 - val_recall: 0.6784 - lr: 1.0000e-06
# Epoch 69/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8874 - precision: 0.9408 - recall: 0.8694
# Epoch 69: val_loss improved from 0.40223 to 0.40194, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8874 - precision: 0.9408 - recall: 0.8694 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8919 - val_recall: 0.6790 - lr: 1.0000e-06
# Epoch 70/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.9972 - dice_coef: 0.8874 - precision: 0.9415 - recall: 0.8680
# Epoch 70: val_loss improved from 0.40194 to 0.40191, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 347ms/step - loss: 0.2723 - accuracy: 0.9972 - dice_coef: 0.8874 - precision: 0.9415 - recall: 0.8680 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8910 - val_recall: 0.6795 - lr: 1.0000e-06
# Epoch 71/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9412 - recall: 0.8682
# Epoch 71: val_loss improved from 0.40191 to 0.40167, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9412 - recall: 0.8682 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7580 - val_precision: 0.8907 - val_recall: 0.6804 - lr: 1.0000e-06
# Epoch 72/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9410 - recall: 0.8662
# Epoch 72: val_loss did not improve from 0.40167
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2729 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9410 - recall: 0.8662 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7578 - val_precision: 0.8914 - val_recall: 0.6795 - lr: 1.0000e-06
# Epoch 73/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9399 - recall: 0.8672
# Epoch 73: val_loss did not improve from 0.40167
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2729 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9399 - recall: 0.8672 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8903 - val_recall: 0.6802 - lr: 1.0000e-06
# Epoch 74/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.9972 - dice_coef: 0.8868 - precision: 0.9406 - recall: 0.8670
# Epoch 74: val_loss improved from 0.40167 to 0.40146, saving model to C:\Projects Datasets\model_details\unet_2\model_2.h5
# 60/60 [==============================] - 21s 349ms/step - loss: 0.2728 - accuracy: 0.9972 - dice_coef: 0.8868 - precision: 0.9406 - recall: 0.8670 - val_loss: 0.4015 - val_accuracy: 0.9948 - val_dice_coef: 0.7581 - val_precision: 0.8902 - val_recall: 0.6808 - lr: 1.0000e-06
# Epoch 75/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2721 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9405 - recall: 0.8696
# Epoch 75: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2721 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9405 - recall: 0.8696 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8914 - val_recall: 0.6793 - lr: 1.0000e-06
# Epoch 76/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.9972 - dice_coef: 0.8870 - precision: 0.9399 - recall: 0.8682
# Epoch 76: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2726 - accuracy: 0.9972 - dice_coef: 0.8870 - precision: 0.9399 - recall: 0.8682 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8925 - val_recall: 0.6784 - lr: 1.0000e-06
# Epoch 77/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8874 - precision: 0.9409 - recall: 0.8678
# Epoch 77: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2722 - accuracy: 0.9972 - dice_coef: 0.8874 - precision: 0.9409 - recall: 0.8678 - val_loss: 0.4018 - val_accuracy: 0.9948 - val_dice_coef: 0.7578 - val_precision: 0.8921 - val_recall: 0.6788 - lr: 1.0000e-06
# Epoch 78/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2721 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9416 - recall: 0.8680
# Epoch 78: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 343ms/step - loss: 0.2721 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9416 - recall: 0.8680 - val_loss: 0.4015 - val_accuracy: 0.9948 - val_dice_coef: 0.7581 - val_precision: 0.8915 - val_recall: 0.6796 - lr: 1.0000e-06
# Epoch 79/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.9972 - dice_coef: 0.8868 - precision: 0.9406 - recall: 0.8672
# Epoch 79: val_loss did not improve from 0.40146
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1e-07.
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2728 - accuracy: 0.9972 - dice_coef: 0.8868 - precision: 0.9406 - recall: 0.8672 - val_loss: 0.4018 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8915 - val_recall: 0.6790 - lr: 1.0000e-06
# Epoch 80/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9972 - dice_coef: 0.8878 - precision: 0.9423 - recall: 0.8669
# Epoch 80: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2717 - accuracy: 0.9972 - dice_coef: 0.8878 - precision: 0.9423 - recall: 0.8669 - val_loss: 0.4020 - val_accuracy: 0.9948 - val_dice_coef: 0.7576 - val_precision: 0.8919 - val_recall: 0.6785 - lr: 1.0000e-07
# Epoch 81/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9424 - recall: 0.8666
# Epoch 81: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9424 - recall: 0.8666 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8915 - val_recall: 0.6789 - lr: 1.0000e-07
# Epoch 82/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9411 - recall: 0.8671
# Epoch 82: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2723 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9411 - recall: 0.8671 - val_loss: 0.4020 - val_accuracy: 0.9948 - val_dice_coef: 0.7576 - val_precision: 0.8918 - val_recall: 0.6786 - lr: 1.0000e-07
# Epoch 83/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.9972 - dice_coef: 0.8887 - precision: 0.9444 - recall: 0.8671
# Epoch 83: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2709 - accuracy: 0.9972 - dice_coef: 0.8887 - precision: 0.9444 - recall: 0.8671 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8918 - val_recall: 0.6787 - lr: 1.0000e-07
# Epoch 84/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.9972 - dice_coef: 0.8873 - precision: 0.9423 - recall: 0.8666
# Epoch 84: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2723 - accuracy: 0.9972 - dice_coef: 0.8873 - precision: 0.9423 - recall: 0.8666 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8917 - val_recall: 0.6788 - lr: 1.0000e-07
# Epoch 85/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9405 - recall: 0.8672
# Epoch 85: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2729 - accuracy: 0.9972 - dice_coef: 0.8867 - precision: 0.9405 - recall: 0.8672 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8917 - val_recall: 0.6787 - lr: 1.0000e-07
# Epoch 86/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9404 - recall: 0.8679
# Epoch 86: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9404 - recall: 0.8679 - val_loss: 0.4019 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8920 - val_recall: 0.6786 - lr: 1.0000e-07
# Epoch 87/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.9972 - dice_coef: 0.8869 - precision: 0.9413 - recall: 0.8669
# Epoch 87: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2727 - accuracy: 0.9972 - dice_coef: 0.8869 - precision: 0.9413 - recall: 0.8669 - val_loss: 0.4018 - val_accuracy: 0.9948 - val_dice_coef: 0.7577 - val_precision: 0.8921 - val_recall: 0.6787 - lr: 1.0000e-07
# Epoch 88/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2712 - accuracy: 0.9972 - dice_coef: 0.8883 - precision: 0.9414 - recall: 0.8691
# Epoch 88: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 346ms/step - loss: 0.2712 - accuracy: 0.9972 - dice_coef: 0.8883 - precision: 0.9414 - recall: 0.8691 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8920 - val_recall: 0.6790 - lr: 1.0000e-07
# Epoch 89/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2721 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9420 - recall: 0.8666
# Epoch 89: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 347ms/step - loss: 0.2721 - accuracy: 0.9972 - dice_coef: 0.8875 - precision: 0.9420 - recall: 0.8666 - val_loss: 0.4016 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8918 - val_recall: 0.6792 - lr: 1.0000e-07
# Epoch 90/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2710 - accuracy: 0.9972 - dice_coef: 0.8886 - precision: 0.9432 - recall: 0.8682
# Epoch 90: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2710 - accuracy: 0.9972 - dice_coef: 0.8886 - precision: 0.9432 - recall: 0.8682 - val_loss: 0.4016 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8917 - val_recall: 0.6792 - lr: 1.0000e-07
# Epoch 91/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.9971 - dice_coef: 0.8863 - precision: 0.9412 - recall: 0.8651
# Epoch 91: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2733 - accuracy: 0.9971 - dice_coef: 0.8863 - precision: 0.9412 - recall: 0.8651 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8918 - val_recall: 0.6791 - lr: 1.0000e-07
# Epoch 92/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.9972 - dice_coef: 0.8883 - precision: 0.9428 - recall: 0.8678
# Epoch 92: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2713 - accuracy: 0.9972 - dice_coef: 0.8883 - precision: 0.9428 - recall: 0.8678 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8918 - val_recall: 0.6790 - lr: 1.0000e-07
# Epoch 93/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9415 - recall: 0.8674
# Epoch 93: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 345ms/step - loss: 0.2724 - accuracy: 0.9972 - dice_coef: 0.8872 - precision: 0.9415 - recall: 0.8674 - val_loss: 0.4017 - val_accuracy: 0.9948 - val_dice_coef: 0.7579 - val_precision: 0.8919 - val_recall: 0.6789 - lr: 1.0000e-07
# Epoch 94/100
# 60/60 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9972 - dice_coef: 0.8879 - precision: 0.9430 - recall: 0.8678
# Epoch 94: val_loss did not improve from 0.40146
# 60/60 [==============================] - 21s 344ms/step - loss: 0.2717 - accuracy: 0.9972 - dice_coef: 0.8879 - precision: 0.9430 - recall: 0.8678 - val_loss: 0.4015 - val_accuracy: 0.9948 - val_dice_coef: 0.7580 - val_precision: 0.8916 - val_recall: 0.6794 - lr: 1.0000e-07

# %%
""" Evaluate on test set """
results = model.evaluate(test_dataset)
print("\nEvaluation Metrics:")
for metric_name, metric_value in zip(model.metrics_names, results):
    print(f"{metric_name}: {metric_value:.4f}")
# Out:
# 20/20 [==============================] - 2s 111ms/step - loss: 0.3954 - accuracy: 0.9947 - dice_coef: 0.7641 - precision: 0.9101 - recall: 0.6855
#
# Evaluation Metrics:
# loss: 0.3954
# accuracy: 0.9947
# dice_coef: 0.7641
# precision: 0.9101
# recall: 0.6855

# %%
import pickle
with open("C:\\Projects Datasets\\model_details\\unet_2\\history2.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %%
import pickle
import matplotlib.pyplot as plt

with open("C:\\Projects Datasets\\model_details\\unet_2\\history2.pkl", "rb") as f:
    history_dict = pickle.load(f)

plt.plot(history_dict['loss'], label='Training Loss')
plt.plot(history_dict['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history_dict['dice_coef'], label='Training Dice Coefficient')
plt.plot(history_dict['val_dice_coef'], label='Validation Dice Coefficient')
plt.xlabel('Epochs')
plt.ylabel('Dice Coefficient')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
print("Final Training Dice:", history_dict['dice_coef'][-1])
print("Final Validation Dice:", history_dict['val_dice_coef'][-1])
# print(history_dict['accuracy'][-1]
# Out:
# Final Training Dice: 0.8878744840621948
# Final Validation Dice: 0.758023738861084

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

model = load_model(
    "C:\\Projects Datasets\\model_details\\unet_2\\model_2.h5",
    custom_objects={"dice_coef": dice_coef},
    compile=False
)

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="binary_crossentropy",  # or dice_loss
    metrics=["accuracy", dice_coef]
)

loss, accuracy, dice = model.evaluate(test_dataset)

print(f"Loss is {loss}")
print(f"Accuracy is {accuracy}")
print(f"Dice_Coef is {dice}")
# Out:
# 20/20 [==============================] - 3s 112ms/step - loss: 0.1934 - accuracy: 0.9947 - dice_coef: 0.7646
# Loss is 0.19338013231754303
# Accuracy is 0.994717001914978
# Dice_Coef is 0.7645682096481323

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\chanu\anaconda3\envs\tensornewgpu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV log
csv_path = "C:\\Projects Datasets\\model_details\\unet_2\\log.csv"
log_data = pd.read_csv(csv_path)

# Inspect available columns
print(log_data.columns)
# Out:
# Index(['epoch', 'accuracy', 'dice_coef', 'loss', 'lr', 'precision', 'recall',
#        'val_accuracy', 'val_dice_coef', 'val_loss', 'val_precision',
#        'val_recall'],
#       dtype='object')

# %%
#https://github.com/nikhilroxtomar/Brain-Tumor-Segmentation-in-TensorFlow-2.0

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    smooth = 1.0
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

# %%
model = load_model("C:\\Projects Datasets\\model_details\\unet_2\\model_2.h5",
                   custom_objects={"dice_coef": dice_coef},
                   compile=False)

# %%
import cv2
import numpy as np

# Load image
img_path = "C:\\Projects Datasets\\model_details\\1111.jpg"
image = cv2.imread(img_path)              # BGR format
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB

# Resize to model input size
image_resized = cv2.resize(image, (256, 256))

# Normalize to [0,1]
image_norm = image_resized / 255.0

# Add batch dimension
input_tensor = np.expand_dims(image_norm, axis=0)   # shape (1, 256, 256, 3)

# %%
pred_mask = model.predict(input_tensor)

# Remove batch dimension
pred_mask = pred_mask[0]

# Threshold (convert probabilities to binary mask)
binary_mask = (pred_mask > 0.5).astype(np.uint8)
# Out:
# 1/1 [==============================] - 1s 680ms/step

# %%
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.imshow(image_resized)
plt.title("Input Image")

plt.subplot(1, 2, 2)
plt.imshow(binary_mask.squeeze(), cmap="gray")
plt.title("Predicted Mask")

plt.show()
