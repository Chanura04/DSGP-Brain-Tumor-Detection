# %%
import os

# %%
image_files=sorted(os.listdir('C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\processed'))
image_files
# Out:
# ['1.png',
#  '10.png',
#  '1000.png',
#  '1001.png',
#  '1002.png',
#  '1003.png',
#  '1004.png',
#  '1005.png',
#  '1006.png',
#  '1007.png',
#  '1009.png',
#  '101.png',
#  '1013.png',
#  '1014.png',
#  '1015.png',
#  '1016.png',
#  '1018.png',
#  '1019.png',
#  '102.png',
#  '1020.png',
#  '1021.png',
#  '1022.png',
#  '1023.png',
#  '1024.png',
#  '1025.png',
#  '1026.png',
#  '1027.png',
#  '1028.png',
#  '1029.png',
#  '103.png',
#  '1030.png',
#  '1031.png',
#  '1032.png',
#  '1033.png',
#  '104.png',
#  '105.png',
#  '106.png',
#  '107.png',
#  '108.png',
#  '109.png',
#  '11.png',
#  '110.png',
#  '112.png',
#  '113.png',
#  '114.png',
#  '115.png',
#  '116.png',
#  '117.png',
#  '118.png',
#  '119.png',
#  '12.png',
#  '120.png',
#  '122.png',
#  '124.png',
#  '125.png',
#  '126.png',
#  '127.png',
#  '1283.png',
#  '1284.png',
#  '1287.png',
#  '1288.png',
#  '1289.png',
#  '129.png',
#  '1290.png',
#  '1291.png',
#  '1292.png',
#  '1299.png',
#  '13.png',
#  '130.png',
# ...

# %%
type(image_files)
# Out:
# list

# %%
image_numbers=[]
for img_num in image_files:
    num=img_num.split('.')[0]
    num=int(num)
    image_numbers.append(num)

# %%
image_numbers
# Out:
# [1,
#  10,
#  1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1009,
#  101,
#  1013,
#  1014,
#  1015,
#  1016,
#  1018,
#  1019,
#  102,
#  1020,
#  1021,
#  1022,
#  1023,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  103,
#  1030,
#  1031,
#  1032,
#  1033,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  11,
#  110,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  12,
#  120,
#  122,
#  124,
#  125,
#  126,
#  127,
#  1283,
#  1284,
#  1287,
#  1288,
#  1289,
#  129,
#  1290,
#  1291,
#  1292,
#  1299,
#  13,
#  130,
#  1301,
#  1302,
#  1304,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  131,
#  1310,
#  1311,
#  1312,
#  1313,
#  1314,
#  1315,
#  1316,
#  1317,
#  1319,
#  132,
#  1320,
#  1321,
#  1322,
#  1323,
#  1324,
#  1325,
#  1326,
#  1327,
#  1328,
#  1329,
#  133,
#  1330,
#  1331,
#  1332,
#  1333,
#  1334,
#  1335,
#  1336,
#  1337,
#  1338,
#  1339,
#  134,
#  1341,
#  1342,
#  1343,
#  1344,
#  1345,
# ...

# %%
mask_files=sorted(os.listdir('C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\masks'))
mask_files
# Out:
# ['1.png',
#  '10.png',
#  '100.png',
#  '1000.png',
#  '1001.png',
#  '1002.png',
#  '1003.png',
#  '1004.png',
#  '1005.png',
#  '1006.png',
#  '1007.png',
#  '1008.png',
#  '1009.png',
#  '101.png',
#  '1010.png',
#  '1011.png',
#  '1012.png',
#  '1013.png',
#  '1014.png',
#  '1015.png',
#  '1016.png',
#  '1017.png',
#  '1018.png',
#  '1019.png',
#  '102.png',
#  '1020.png',
#  '1021.png',
#  '1022.png',
#  '1023.png',
#  '1024.png',
#  '1025.png',
#  '1026.png',
#  '1027.png',
#  '1028.png',
#  '1029.png',
#  '103.png',
#  '1030.png',
#  '1031.png',
#  '1032.png',
#  '1033.png',
#  '1034.png',
#  '1035.png',
#  '1036.png',
#  '1037.png',
#  '1038.png',
#  '1039.png',
#  '104.png',
#  '1040.png',
#  '1041.png',
#  '1042.png',
#  '1043.png',
#  '1044.png',
#  '1045.png',
#  '1046.png',
#  '1047.png',
#  '1048.png',
#  '1049.png',
#  '105.png',
#  '1050.png',
#  '1051.png',
#  '1052.png',
#  '1053.png',
#  '1054.png',
#  '1055.png',
#  '1056.png',
#  '1057.png',
#  '1058.png',
# ...

# %%
len(image_files)
# Out:
# 882

# %%
len(mask_files)
# Out:
# 3052

# %%
mask_numbers=[]
for mask_num in image_files:
    num=mask_num.split('.')[0]
    num=int(num)
    mask_numbers.append(num)

# %%
result = [x for x in mask_numbers if x not in image_numbers]
print(result)

for num in result:
    mask_numbers.remove(num)
len(mask_numbers)
# Out:
# []
# 882

# %%
result = [x for x in image_numbers if x not in mask_numbers]
print(result)

for num in result:
    image_numbers.remove(num)
len(image_numbers)
# Out:
# []
# 882

# %%
folder_A = "C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\processed"
folder_B = "C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\masks"

# Get filenames only
files_A = set(os.listdir(folder_A))
files_B = set(os.listdir(folder_B))

# Files in A but NOT in B
files_to_remove = files_A - files_B

print(f"Files to be removed: {len(files_to_remove)}")

for filename in files_to_remove:
    file_path = os.path.join(folder_A, filename)

    # Make sure it's a file (not a folder)
    if os.path.isfile(file_path):
        os.remove(file_path)
        print(f"Removed: {filename}")
# Out:
# Files to be removed: 0

# %%
folder_B = "C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\processed"
folder_A = "C:\Projects Datasets\Segmentation_1\Segmentation_filtered\\masks"

# Get filenames only
files_A = set(os.listdir(folder_A))
files_B = set(os.listdir(folder_B))

# Files in A but NOT in B
files_to_remove = files_A - files_B

print(f"Files to be removed: {len(files_to_remove)}")

for filename in files_to_remove:
    file_path = os.path.join(folder_A, filename)

    # Make sure it's a file (not a folder)
    if os.path.isfile(file_path):
        os.remove(file_path)
        print(f"Removed: {filename}")
# Out:
# Files to be removed: 2170
# Removed: 1522.png
# Removed: 2586.png
# Removed: 1435.png
# Removed: 1633.png
# Removed: 2327.png
# Removed: 370.png
# Removed: 1574.png
# Removed: 1238.png
# Removed: 2466.png
# Removed: 2957.png
# Removed: 643.png
# Removed: 1713.png
# Removed: 2283.png
# Removed: 761.png
# Removed: 313.png
# Removed: 2961.png
# Removed: 2657.png
# Removed: 1662.png
# Removed: 2765.png
# Removed: 650.png
# Removed: 2920.png
# Removed: 1096.png
# Removed: 379.png
# Removed: 2415.png
# Removed: 556.png
# Removed: 1656.png
# Removed: 2467.png
# Removed: 2892.png
# Removed: 520.png
# Removed: 2659.png
# Removed: 2779.png
# Removed: 2987.png
# Removed: 492.png
# Removed: 2766.png
# Removed: 1278.png
# Removed: 303.png
# Removed: 2746.png
# Removed: 1491.png
# Removed: 2858.png
# Removed: 266.png
# Removed: 1184.png
# Removed: 2432.png
# Removed: 1624.png
# Removed: 3046.png
# Removed: 1592.png
# Removed: 967.png
# Removed: 660.png
# Removed: 814.png
# Removed: 1687.png
# ...
